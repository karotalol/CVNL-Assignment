# %% [markdown]
# CNN Visual Classification (Aircraft Family)
#
# Convolutional Neural Network (CNN) image classifier to recognise 5 aircraft types.
#
# Plane Types: A320, A340, A380, B737, B777
#
# Used transfer learning with a pretrained ResNet18 model, then progressively improve performance across three iterations by:
# 1. Training a new classifier head
# 2. Fine-tuning deeper layers with augmentation
# 3. Addressing plane type imbalance using weighted CrossEntropyLoss

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Dataset used is the FGVC-Aircraft dataset which contains aircraft images labelled by aircraft types.

# %%
# !cp /content/drive/MyDrive/fgvc-aircraft-2013b.tar.gz .
# !cp /content/drive/MyDrive/fgvc-aircraft-2013b-annotations.tar.gz .
# !ls
# Out:
# aircraft5  fgvc-aircraft-2013b			   fgvc-aircraft-2013b.tar.gz
# drive	   fgvc-aircraft-2013b-annotations.tar.gz  sample_data

# %%
# !tar -xvf fgvc-aircraft-2013b.tar.gz
# !tar -xvf fgvc-aircraft-2013b-annotations.tar.gz
# Out:
# Streaming output truncated to the last 5000 lines.
# fgvc-aircraft-2013b/data/images/1349345.jpg
# fgvc-aircraft-2013b/data/images/0894316.jpg
# fgvc-aircraft-2013b/data/images/1244306.jpg
# fgvc-aircraft-2013b/data/images/1396258.jpg
# fgvc-aircraft-2013b/data/images/1534214.jpg
# fgvc-aircraft-2013b/data/images/0275792.jpg
# fgvc-aircraft-2013b/data/images/0345781.jpg
# fgvc-aircraft-2013b/data/images/1754078.jpg
# fgvc-aircraft-2013b/data/images/1818166.jpg
# fgvc-aircraft-2013b/data/images/0469140.jpg
# fgvc-aircraft-2013b/data/images/1839235.jpg
# fgvc-aircraft-2013b/data/images/2074712.jpg
# fgvc-aircraft-2013b/data/images/0302207.jpg
# fgvc-aircraft-2013b/data/images/0169635.jpg
# fgvc-aircraft-2013b/data/images/1879116.jpg
# fgvc-aircraft-2013b/data/images/1420123.jpg
# fgvc-aircraft-2013b/data/images/1773176.jpg
# fgvc-aircraft-2013b/data/images/1106369.jpg
# fgvc-aircraft-2013b/data/images/0547020.jpg
# fgvc-aircraft-2013b/data/images/0779581.jpg
# fgvc-aircraft-2013b/data/images/0522830.jpg
# fgvc-aircraft-2013b/data/images/1637438.jpg
# fgvc-aircraft-2013b/data/images/2240083.jpg
# fgvc-aircraft-2013b/data/images/1291802.jpg
# fgvc-aircraft-2013b/data/images/1093250.jpg
# fgvc-aircraft-2013b/data/images/1368847.jpg
# fgvc-aircraft-2013b/data/images/1624193.jpg
# fgvc-aircraft-2013b/data/images/1184708.jpg
# fgvc-aircraft-2013b/data/images/1747768.jpg
# fgvc-aircraft-2013b/data/images/0923717.jpg
# fgvc-aircraft-2013b/data/images/2147406.jpg
# fgvc-aircraft-2013b/data/images/0218848.jpg
# fgvc-aircraft-2013b/data/images/1950555.jpg
# fgvc-aircraft-2013b/data/images/1102089.jpg
# fgvc-aircraft-2013b/data/images/0102560.jpg
# fgvc-aircraft-2013b/data/images/0771794.jpg
# fgvc-aircraft-2013b/data/images/1993167.jpg
# fgvc-aircraft-2013b/data/images/1889572.jpg
# fgvc-aircraft-2013b/data/images/1376745.jpg
# fgvc-aircraft-2013b/data/images/1428349.jpg
# fgvc-aircraft-2013b/data/images/0636482.jpg
# fgvc-aircraft-2013b/data/images/1352223.jpg
# fgvc-aircraft-2013b/data/images/0582367.jpg
# fgvc-aircraft-2013b/data/images/2259663.jpg
# fgvc-aircraft-2013b/data/images/0853775.jpg
# fgvc-aircraft-2013b/data/images/1031455.jpg
# fgvc-aircraft-2013b/data/images/1673535.jpg
# fgvc-aircraft-2013b/data/images/1449582.jpg
# fgvc-aircraft-2013b/data/images/2169125.jpg
# fgvc-aircraft-2013b/data/images/1574580.jpg
# fgvc-aircraft-2013b/data/images/1410104.jpg
# fgvc-aircraft-2013b/data/images/0302019.jpg
# fgvc-aircraft-2013b/data/images/1043776.jpg
# fgvc-aircraft-2013b/data/images/0460483.jpg
# fgvc-aircraft-2013b/data/images/1296833.jpg
# fgvc-aircraft-2013b/data/images/1315760.jpg
# fgvc-aircraft-2013b/data/images/1908679.jpg
# fgvc-aircraft-2013b/data/images/1611219.jpg
# fgvc-aircraft-2013b/data/images/0114407.jpg
# fgvc-aircraft-2013b/data/images/1736158.jpg
# fgvc-aircraft-2013b/data/images/0730739.jpg
# fgvc-aircraft-2013b/data/images/1234230.jpg
# fgvc-aircraft-2013b/data/images/1467694.jpg
# fgvc-aircraft-2013b/data/images/0524795.jpg
# fgvc-aircraft-2013b/data/images/1233576.jpg
# fgvc-aircraft-2013b/data/images/2166004.jpg
# fgvc-aircraft-2013b/data/images/1961234.jpg
# fgvc-aircraft-2013b/data/images/1201556.jpg
# fgvc-aircraft-2013b/data/images/2105989.jpg
# fgvc-aircraft-2013b/data/images/0523183.jpg
# fgvc-aircraft-2013b/data/images/0302006.jpg
# fgvc-aircraft-2013b/data/images/0705082.jpg
# fgvc-aircraft-2013b/data/images/0136160.jpg
# fgvc-aircraft-2013b/data/images/0819084.jpg
# fgvc-aircraft-2013b/data/images/1745719.jpg
# fgvc-aircraft-2013b/data/images/1211875.jpg
# fgvc-aircraft-2013b/data/images/2070644.jpg
# fgvc-aircraft-2013b/data/images/1869886.jpg
# fgvc-aircraft-2013b/data/images/1296212.jpg
# fgvc-aircraft-2013b/data/images/0061136.jpg
# fgvc-aircraft-2013b/data/images/1316268.jpg
# fgvc-aircraft-2013b/data/images/1168800.jpg
# fgvc-aircraft-2013b/data/images/0896106.jpg
# fgvc-aircraft-2013b/data/images/2070659.jpg
# fgvc-aircraft-2013b/data/images/0931601.jpg
# fgvc-aircraft-2013b/data/images/1545982.jpg
# fgvc-aircraft-2013b/data/images/0127649.jpg
# fgvc-aircraft-2013b/data/images/0553599.jpg
# fgvc-aircraft-2013b/data/images/1244766.jpg
# fgvc-aircraft-2013b/data/images/0977899.jpg
# fgvc-aircraft-2013b/data/images/1603035.jpg
# fgvc-aircraft-2013b/data/images/1022616.jpg
# fgvc-aircraft-2013b/data/images/1158131.jpg
# fgvc-aircraft-2013b/data/images/0924092.jpg
# fgvc-aircraft-2013b/data/images/1748171.jpg
# fgvc-aircraft-2013b/data/images/0447769.jpg
# fgvc-aircraft-2013b/data/images/1230044.jpg
# fgvc-aircraft-2013b/data/images/2124427.jpg
# fgvc-aircraft-2013b/data/images/2229397.jpg
# fgvc-aircraft-2013b/data/images/0924311.jpg
# fgvc-aircraft-2013b/data/images/1000045.jpg
# fgvc-aircraft-2013b/data/images/1513616.jpg
# fgvc-aircraft-2013b/data/images/0522857.jpg
# fgvc-aircraft-2013b/data/images/1658586.jpg
# fgvc-aircraft-2013b/data/images/1338874.jpg
# fgvc-aircraft-2013b/data/images/0570728.jpg
# fgvc-aircraft-2013b/data/images/0950562.jpg
# fgvc-aircraft-2013b/data/images/0275123.jpg
# fgvc-aircraft-2013b/data/images/1730671.jpg
# fgvc-aircraft-2013b/data/images/1193562.jpg
# fgvc-aircraft-2013b/data/images/1605155.jpg
# fgvc-aircraft-2013b/data/images/1363578.jpg
# fgvc-aircraft-2013b/data/images/0719543.jpg
# fgvc-aircraft-2013b/data/images/0601227.jpg
# fgvc-aircraft-2013b/data/images/0100206.jpg
# fgvc-aircraft-2013b/data/images/0709332.jpg
# fgvc-aircraft-2013b/data/images/1531356.jpg
# fgvc-aircraft-2013b/data/images/1846149.jpg
# fgvc-aircraft-2013b/data/images/1941845.jpg
# fgvc-aircraft-2013b/data/images/0459278.jpg
# fgvc-aircraft-2013b/data/images/1879894.jpg
# fgvc-aircraft-2013b/data/images/1539455.jpg
# fgvc-aircraft-2013b/data/images/1312496.jpg
# fgvc-aircraft-2013b/data/images/0130599.jpg
# fgvc-aircraft-2013b/data/images/1349217.jpg
# fgvc-aircraft-2013b/data/images/1328048.jpg
# fgvc-aircraft-2013b/data/images/1146228.jpg
# fgvc-aircraft-2013b/data/images/0895290.jpg
# fgvc-aircraft-2013b/data/images/0773536.jpg
# fgvc-aircraft-2013b/data/images/1371565.jpg
# fgvc-aircraft-2013b/data/images/0792175.jpg
# fgvc-aircraft-2013b/data/images/0114415.jpg
# fgvc-aircraft-2013b/data/images/1549874.jpg
# fgvc-aircraft-2013b/data/images/0901374.jpg
# fgvc-aircraft-2013b/data/images/0447806.jpg
# fgvc-aircraft-2013b/data/images/1567881.jpg
# fgvc-aircraft-2013b/data/images/1749597.jpg
# fgvc-aircraft-2013b/data/images/1469699.jpg
# fgvc-aircraft-2013b/data/images/1243068.jpg
# fgvc-aircraft-2013b/data/images/0713752.jpg
# fgvc-aircraft-2013b/data/images/1321494.jpg
# fgvc-aircraft-2013b/data/images/0481841.jpg
# fgvc-aircraft-2013b/data/images/1481647.jpg
# fgvc-aircraft-2013b/data/images/0127504.jpg
# fgvc-aircraft-2013b/data/images/0382062.jpg
# fgvc-aircraft-2013b/data/images/1251519.jpg
# fgvc-aircraft-2013b/data/images/1124489.jpg
# fgvc-aircraft-2013b/data/images/1527486.jpg
# fgvc-aircraft-2013b/data/images/2033183.jpg
# fgvc-aircraft-2013b/data/images/1997993.jpg
# fgvc-aircraft-2013b/data/images/0451224.jpg
# fgvc-aircraft-2013b/data/images/0271186.jpg
# fgvc-aircraft-2013b/data/images/1806237.jpg
# fgvc-aircraft-2013b/data/images/1946040.jpg
# fgvc-aircraft-2013b/data/images/0702843.jpg
# fgvc-aircraft-2013b/data/images/1826521.jpg
# fgvc-aircraft-2013b/data/images/0857653.jpg
# fgvc-aircraft-2013b/data/images/1156768.jpg
# fgvc-aircraft-2013b/data/images/2188604.jpg
# fgvc-aircraft-2013b/data/images/0527682.jpg
# fgvc-aircraft-2013b/data/images/1688962.jpg
# fgvc-aircraft-2013b/data/images/0935361.jpg
# fgvc-aircraft-2013b/data/images/0924085.jpg
# fgvc-aircraft-2013b/data/images/1285916.jpg
# fgvc-aircraft-2013b/data/images/1648294.jpg
# fgvc-aircraft-2013b/data/images/1313344.jpg
# fgvc-aircraft-2013b/data/images/0781154.jpg
# fgvc-aircraft-2013b/data/images/2213539.jpg
# fgvc-aircraft-2013b/data/images/1243688.jpg
# fgvc-aircraft-2013b/data/images/1918572.jpg
# fgvc-aircraft-2013b/data/images/0517625.jpg
# fgvc-aircraft-2013b/data/images/1245215.jpg
# fgvc-aircraft-2013b/data/images/1237622.jpg
# fgvc-aircraft-2013b/data/images/1713971.jpg
# fgvc-aircraft-2013b/data/images/1031465.jpg
# fgvc-aircraft-2013b/data/images/0782933.jpg
# fgvc-aircraft-2013b/data/images/1054576.jpg
# fgvc-aircraft-2013b/data/images/1806228.jpg
# fgvc-aircraft-2013b/data/images/1446341.jpg
# fgvc-aircraft-2013b/data/images/1351207.jpg
# fgvc-aircraft-2013b/data/images/0602750.jpg
# fgvc-aircraft-2013b/data/images/1561989.jpg
# fgvc-aircraft-2013b/data/images/2121969.jpg
# fgvc-aircraft-2013b/data/images/1106412.jpg
# fgvc-aircraft-2013b/data/images/1394145.jpg
# fgvc-aircraft-2013b/data/images/0365342.jpg
# fgvc-aircraft-2013b/data/images/0523031.jpg
# fgvc-aircraft-2013b/data/images/0548761.jpg
# fgvc-aircraft-2013b/data/images/1784221.jpg
# fgvc-aircraft-2013b/data/images/1872634.jpg
# fgvc-aircraft-2013b/data/images/1277986.jpg
# fgvc-aircraft-2013b/data/images/1860537.jpg
# fgvc-aircraft-2013b/data/images/1926379.jpg
# fgvc-aircraft-2013b/data/images/2208641.jpg
# fgvc-aircraft-2013b/data/images/0857160.jpg
# fgvc-aircraft-2013b/data/images/2096267.jpg
# fgvc-aircraft-2013b/data/images/1707575.jpg
# fgvc-aircraft-2013b/data/images/0620009.jpg
# fgvc-aircraft-2013b/data/images/0870866.jpg
# fgvc-aircraft-2013b/data/images/1663628.jpg
# fgvc-aircraft-2013b/data/images/0523272.jpg
# fgvc-aircraft-2013b/data/images/0921181.jpg
# fgvc-aircraft-2013b/data/images/1119554.jpg
# fgvc-aircraft-2013b/data/images/1879895.jpg
# fgvc-aircraft-2013b/data/images/0447777.jpg
# fgvc-aircraft-2013b/data/images/1686317.jpg
# fgvc-aircraft-2013b/data/images/1151753.jpg
# fgvc-aircraft-2013b/data/images/0143389.jpg
# fgvc-aircraft-2013b/data/images/0172093.jpg
# fgvc-aircraft-2013b/data/images/0147028.jpg
# fgvc-aircraft-2013b/data/images/1833079.jpg
# fgvc-aircraft-2013b/data/images/2218842.jpg
# fgvc-aircraft-2013b/data/images/0713739.jpg
# fgvc-aircraft-2013b/data/images/1342280.jpg
# fgvc-aircraft-2013b/data/images/1956397.jpg
# fgvc-aircraft-2013b/data/images/1142906.jpg
# fgvc-aircraft-2013b/data/images/1719986.jpg
# fgvc-aircraft-2013b/data/images/1421346.jpg
# fgvc-aircraft-2013b/data/images/0201665.jpg
# fgvc-aircraft-2013b/data/images/1356931.jpg
# fgvc-aircraft-2013b/data/images/0276023.jpg
# fgvc-aircraft-2013b/data/images/0691271.jpg
# fgvc-aircraft-2013b/data/images/0918624.jpg
# fgvc-aircraft-2013b/data/images/1511412.jpg
# fgvc-aircraft-2013b/data/images/0458781.jpg
# fgvc-aircraft-2013b/data/images/1470663.jpg
# fgvc-aircraft-2013b/data/images/1864991.jpg
# fgvc-aircraft-2013b/data/images/1204566.jpg
# fgvc-aircraft-2013b/data/images/0724121.jpg
# fgvc-aircraft-2013b/data/images/1067522.jpg
# fgvc-aircraft-2013b/data/images/1736099.jpg
# fgvc-aircraft-2013b/data/images/2226825.jpg
# fgvc-aircraft-2013b/data/images/1328043.jpg
# fgvc-aircraft-2013b/data/images/2153514.jpg
# fgvc-aircraft-2013b/data/images/0368357.jpg
# fgvc-aircraft-2013b/data/images/0064933.jpg
# fgvc-aircraft-2013b/data/images/2054441.jpg
# fgvc-aircraft-2013b/data/images/0885288.jpg
# fgvc-aircraft-2013b/data/images/0485221.jpg
# fgvc-aircraft-2013b/data/images/1401606.jpg
# fgvc-aircraft-2013b/data/images/1564413.jpg
# fgvc-aircraft-2013b/data/images/1654785.jpg
# fgvc-aircraft-2013b/data/images/0593173.jpg
# fgvc-aircraft-2013b/data/images/1222170.jpg
# fgvc-aircraft-2013b/data/images/1917518.jpg
# fgvc-aircraft-2013b/data/images/0753360.jpg
# fgvc-aircraft-2013b/data/images/1725769.jpg
# fgvc-aircraft-2013b/data/images/0302935.jpg
# fgvc-aircraft-2013b/data/images/0554718.jpg
# fgvc-aircraft-2013b/data/images/1296580.jpg
# fgvc-aircraft-2013b/data/images/1542460.jpg
# fgvc-aircraft-2013b/data/images/1374642.jpg
# fgvc-aircraft-2013b/data/images/1344355.jpg
# fgvc-aircraft-2013b/data/images/1119094.jpg
# fgvc-aircraft-2013b/data/images/0704265.jpg
# fgvc-aircraft-2013b/data/images/0802262.jpg
# fgvc-aircraft-2013b/data/images/1193603.jpg
# fgvc-aircraft-2013b/data/images/1043782.jpg
# fgvc-aircraft-2013b/data/images/1294569.jpg
# fgvc-aircraft-2013b/data/images/0386926.jpg
# fgvc-aircraft-2013b/data/images/0063284.jpg
# fgvc-aircraft-2013b/data/images/1277982.jpg
# fgvc-aircraft-2013b/data/images/1818747.jpg
# fgvc-aircraft-2013b/data/images/0062131.jpg
# fgvc-aircraft-2013b/data/images/0448049.jpg
# fgvc-aircraft-2013b/data/images/0574357.jpg
# fgvc-aircraft-2013b/data/images/1633282.jpg
# fgvc-aircraft-2013b/data/images/1707576.jpg
# fgvc-aircraft-2013b/data/images/0458647.jpg
# fgvc-aircraft-2013b/data/images/0240325.jpg
# fgvc-aircraft-2013b/data/images/1060375.jpg
# fgvc-aircraft-2013b/data/images/1158575.jpg
# fgvc-aircraft-2013b/data/images/1772714.jpg
# fgvc-aircraft-2013b/data/images/0114430.jpg
# fgvc-aircraft-2013b/data/images/1838529.jpg
# fgvc-aircraft-2013b/data/images/2118958.jpg
# fgvc-aircraft-2013b/data/images/1469709.jpg
# fgvc-aircraft-2013b/data/images/0188143.jpg
# fgvc-aircraft-2013b/data/images/0558296.jpg
# fgvc-aircraft-2013b/data/images/0483570.jpg
# fgvc-aircraft-2013b/data/images/1293223.jpg
# fgvc-aircraft-2013b/data/images/1240324.jpg
# fgvc-aircraft-2013b/data/images/1774585.jpg
# fgvc-aircraft-2013b/data/images/0143377.jpg
# fgvc-aircraft-2013b/data/images/2137130.jpg
# fgvc-aircraft-2013b/data/images/1284367.jpg
# fgvc-aircraft-2013b/data/images/2197895.jpg
# fgvc-aircraft-2013b/data/images/1351410.jpg
# fgvc-aircraft-2013b/data/images/0521359.jpg
# fgvc-aircraft-2013b/data/images/0149342.jpg
# fgvc-aircraft-2013b/data/images/1426711.jpg
# fgvc-aircraft-2013b/data/images/0548186.jpg
# fgvc-aircraft-2013b/data/images/1688324.jpg
# fgvc-aircraft-2013b/data/images/1298765.jpg
# fgvc-aircraft-2013b/data/images/2006683.jpg
# fgvc-aircraft-2013b/data/images/2139677.jpg
# fgvc-aircraft-2013b/data/images/1182360.jpg
# fgvc-aircraft-2013b/data/images/2037389.jpg
# fgvc-aircraft-2013b/data/images/1299601.jpg
# fgvc-aircraft-2013b/data/images/0704276.jpg
# fgvc-aircraft-2013b/data/images/1606079.jpg
# fgvc-aircraft-2013b/data/images/1335478.jpg
# fgvc-aircraft-2013b/data/images/1377234.jpg
# fgvc-aircraft-2013b/data/images/0422707.jpg
# fgvc-aircraft-2013b/data/images/1540297.jpg
# fgvc-aircraft-2013b/data/images/0963962.jpg
# fgvc-aircraft-2013b/data/images/1942551.jpg
# fgvc-aircraft-2013b/data/images/2000146.jpg
# fgvc-aircraft-2013b/data/images/2065885.jpg
# fgvc-aircraft-2013b/data/images/2075500.jpg
# fgvc-aircraft-2013b/data/images/0225217.jpg
# fgvc-aircraft-2013b/data/images/1094917.jpg
# fgvc-aircraft-2013b/data/images/0676942.jpg
# fgvc-aircraft-2013b/data/images/1730979.jpg
# fgvc-aircraft-2013b/data/images/2231271.jpg
# fgvc-aircraft-2013b/data/images/0980635.jpg
# fgvc-aircraft-2013b/data/images/0875346.jpg
# fgvc-aircraft-2013b/data/images/0944156.jpg
# fgvc-aircraft-2013b/data/images/0688093.jpg
# fgvc-aircraft-2013b/data/images/1674645.jpg
# fgvc-aircraft-2013b/data/images/2162821.jpg
# fgvc-aircraft-2013b/data/images/1173007.jpg
# fgvc-aircraft-2013b/data/images/0454534.jpg
# fgvc-aircraft-2013b/data/images/1397531.jpg
# fgvc-aircraft-2013b/data/images/0554595.jpg
# fgvc-aircraft-2013b/data/images/0136181.jpg
# fgvc-aircraft-2013b/data/images/1725804.jpg
# fgvc-aircraft-2013b/data/images/1152153.jpg
# fgvc-aircraft-2013b/data/images/1663379.jpg
# fgvc-aircraft-2013b/data/images/1088345.jpg
# fgvc-aircraft-2013b/data/images/2227595.jpg
# fgvc-aircraft-2013b/data/images/0918184.jpg
# fgvc-aircraft-2013b/data/images/0136468.jpg
# fgvc-aircraft-2013b/data/images/0944257.jpg
# fgvc-aircraft-2013b/data/images/1614884.jpg
# fgvc-aircraft-2013b/data/images/0773076.jpg
# fgvc-aircraft-2013b/data/images/0687610.jpg
# fgvc-aircraft-2013b/data/images/2169490.jpg
# fgvc-aircraft-2013b/data/images/0225218.jpg
# fgvc-aircraft-2013b/data/images/1102455.jpg
# fgvc-aircraft-2013b/data/images/2238327.jpg
# fgvc-aircraft-2013b/data/images/0574359.jpg
# fgvc-aircraft-2013b/data/images/2248561.jpg
# fgvc-aircraft-2013b/data/images/1092262.jpg
# fgvc-aircraft-2013b/data/images/1044149.jpg
# fgvc-aircraft-2013b/data/images/1979061.jpg
# fgvc-aircraft-2013b/data/images/1105737.jpg
# fgvc-aircraft-2013b/data/images/2131704.jpg
# fgvc-aircraft-2013b/data/images/0043890.jpg
# fgvc-aircraft-2013b/data/images/1355218.jpg
# fgvc-aircraft-2013b/data/images/1395431.jpg
# fgvc-aircraft-2013b/data/images/1338551.jpg
# fgvc-aircraft-2013b/data/images/2223757.jpg
# fgvc-aircraft-2013b/data/images/0926148.jpg
# fgvc-aircraft-2013b/data/images/0070035.jpg
# fgvc-aircraft-2013b/data/images/1969071.jpg
# fgvc-aircraft-2013b/data/images/1857204.jpg
# fgvc-aircraft-2013b/data/images/1808795.jpg
# fgvc-aircraft-2013b/data/images/1501931.jpg
# fgvc-aircraft-2013b/data/images/0814906.jpg
# fgvc-aircraft-2013b/data/images/1484701.jpg
# fgvc-aircraft-2013b/data/images/0796384.jpg
# fgvc-aircraft-2013b/data/images/1631148.jpg
# fgvc-aircraft-2013b/data/images/0447935.jpg
# fgvc-aircraft-2013b/data/images/0562553.jpg
# fgvc-aircraft-2013b/data/images/0328235.jpg
# fgvc-aircraft-2013b/data/images/2118302.jpg
# fgvc-aircraft-2013b/data/images/1469089.jpg
# fgvc-aircraft-2013b/data/images/0953562.jpg
# fgvc-aircraft-2013b/data/images/1447976.jpg
# fgvc-aircraft-2013b/data/images/0143371.jpg
# fgvc-aircraft-2013b/data/images/1154702.jpg
# fgvc-aircraft-2013b/data/images/1113092.jpg
# fgvc-aircraft-2013b/data/images/0848172.jpg
# fgvc-aircraft-2013b/data/images/0063053.jpg
# fgvc-aircraft-2013b/data/images/1151769.jpg
# fgvc-aircraft-2013b/data/images/1215875.jpg
# fgvc-aircraft-2013b/data/images/0989831.jpg
# fgvc-aircraft-2013b/data/images/1304025.jpg
# fgvc-aircraft-2013b/data/images/0942162.jpg
# fgvc-aircraft-2013b/data/images/0383679.jpg
# fgvc-aircraft-2013b/data/images/1816331.jpg
# fgvc-aircraft-2013b/data/images/1692498.jpg
# fgvc-aircraft-2013b/data/images/1204180.jpg
# fgvc-aircraft-2013b/data/images/1348827.jpg
# fgvc-aircraft-2013b/data/images/1052314.jpg
# fgvc-aircraft-2013b/data/images/1384548.jpg
# fgvc-aircraft-2013b/data/images/1647702.jpg
# fgvc-aircraft-2013b/data/images/1417441.jpg
# fgvc-aircraft-2013b/data/images/1882639.jpg
# fgvc-aircraft-2013b/data/images/1611095.jpg
# fgvc-aircraft-2013b/data/images/2238661.jpg
# fgvc-aircraft-2013b/data/images/2231825.jpg
# fgvc-aircraft-2013b/data/images/1795700.jpg
# fgvc-aircraft-2013b/data/images/1560581.jpg
# fgvc-aircraft-2013b/data/images/1739105.jpg
# fgvc-aircraft-2013b/data/images/2021843.jpg
# fgvc-aircraft-2013b/data/images/1083206.jpg
# fgvc-aircraft-2013b/data/images/1609206.jpg
# fgvc-aircraft-2013b/data/images/0457841.jpg
# fgvc-aircraft-2013b/data/images/1621237.jpg
# fgvc-aircraft-2013b/data/images/1054022.jpg
# fgvc-aircraft-2013b/data/images/1062510.jpg
# fgvc-aircraft-2013b/data/images/1014363.jpg
# fgvc-aircraft-2013b/data/images/0143363.jpg
# fgvc-aircraft-2013b/data/images/0454781.jpg
# fgvc-aircraft-2013b/data/images/1115130.jpg
# fgvc-aircraft-2013b/data/images/1650403.jpg
# fgvc-aircraft-2013b/data/images/1700857.jpg
# fgvc-aircraft-2013b/data/images/0457849.jpg
# fgvc-aircraft-2013b/data/images/1861474.jpg
# fgvc-aircraft-2013b/data/images/0487356.jpg
# fgvc-aircraft-2013b/data/images/2187803.jpg
# fgvc-aircraft-2013b/data/images/1626934.jpg
# fgvc-aircraft-2013b/data/images/0184373.jpg
# fgvc-aircraft-2013b/data/images/0737678.jpg
# fgvc-aircraft-2013b/data/images/1541799.jpg
# fgvc-aircraft-2013b/data/images/1373275.jpg
# fgvc-aircraft-2013b/data/images/0758130.jpg
# fgvc-aircraft-2013b/data/images/0225206.jpg
# fgvc-aircraft-2013b/data/images/1541601.jpg
# fgvc-aircraft-2013b/data/images/1605117.jpg
# fgvc-aircraft-2013b/data/images/0409532.jpg
# fgvc-aircraft-2013b/data/images/1691787.jpg
# fgvc-aircraft-2013b/data/images/0610657.jpg
# fgvc-aircraft-2013b/data/images/1395798.jpg
# fgvc-aircraft-2013b/data/images/0829651.jpg
# fgvc-aircraft-2013b/data/images/1952834.jpg
# fgvc-aircraft-2013b/data/images/0175724.jpg
# fgvc-aircraft-2013b/data/images/1818870.jpg
# fgvc-aircraft-2013b/data/images/1106454.jpg
# fgvc-aircraft-2013b/data/images/2128002.jpg
# fgvc-aircraft-2013b/data/images/1831097.jpg
# fgvc-aircraft-2013b/data/images/0897300.jpg
# fgvc-aircraft-2013b/data/images/2057952.jpg
# fgvc-aircraft-2013b/data/images/1296186.jpg
# fgvc-aircraft-2013b/data/images/0218791.jpg
# fgvc-aircraft-2013b/data/images/1785635.jpg
# fgvc-aircraft-2013b/data/images/1790439.jpg
# fgvc-aircraft-2013b/data/images/0996579.jpg
# fgvc-aircraft-2013b/data/images/1610421.jpg
# fgvc-aircraft-2013b/data/images/1927216.jpg
# fgvc-aircraft-2013b/data/images/1126597.jpg
# fgvc-aircraft-2013b/data/images/2260089.jpg
# fgvc-aircraft-2013b/data/images/1453508.jpg
# fgvc-aircraft-2013b/data/images/1636453.jpg
# fgvc-aircraft-2013b/data/images/2188100.jpg
# fgvc-aircraft-2013b/data/images/1112646.jpg
# fgvc-aircraft-2013b/data/images/1427112.jpg
# fgvc-aircraft-2013b/data/images/1328044.jpg
# fgvc-aircraft-2013b/data/images/1886145.jpg
# fgvc-aircraft-2013b/data/images/0275117.jpg
# fgvc-aircraft-2013b/data/images/2128061.jpg
# fgvc-aircraft-2013b/data/images/1116484.jpg
# fgvc-aircraft-2013b/data/images/0928680.jpg
# fgvc-aircraft-2013b/data/images/1824419.jpg
# fgvc-aircraft-2013b/data/images/0063286.jpg
# fgvc-aircraft-2013b/data/images/0758132.jpg
# fgvc-aircraft-2013b/data/images/0713740.jpg
# fgvc-aircraft-2013b/data/images/1036818.jpg
# fgvc-aircraft-2013b/data/images/1518619.jpg
# fgvc-aircraft-2013b/data/images/1276588.jpg
# fgvc-aircraft-2013b/data/images/2239292.jpg
# fgvc-aircraft-2013b/data/images/2111853.jpg
# fgvc-aircraft-2013b/data/images/0939541.jpg
# fgvc-aircraft-2013b/data/images/0154349.jpg
# fgvc-aircraft-2013b/data/images/1864330.jpg
# fgvc-aircraft-2013b/data/images/1050956.jpg
# fgvc-aircraft-2013b/data/images/1261956.jpg
# fgvc-aircraft-2013b/data/images/1998936.jpg
# fgvc-aircraft-2013b/data/images/2209714.jpg
# fgvc-aircraft-2013b/data/images/2173352.jpg
# fgvc-aircraft-2013b/data/images/1370959.jpg
# fgvc-aircraft-2013b/data/images/0522967.jpg
# fgvc-aircraft-2013b/data/images/1349343.jpg
# fgvc-aircraft-2013b/data/images/1713266.jpg
# fgvc-aircraft-2013b/data/images/0673508.jpg
# fgvc-aircraft-2013b/data/images/0939519.jpg
# fgvc-aircraft-2013b/data/images/0313723.jpg
# fgvc-aircraft-2013b/data/images/1146230.jpg
# fgvc-aircraft-2013b/data/images/1054467.jpg
# fgvc-aircraft-2013b/data/images/0920417.jpg
# fgvc-aircraft-2013b/data/images/0681458.jpg
# fgvc-aircraft-2013b/data/images/0684607.jpg
# fgvc-aircraft-2013b/data/images/0494461.jpg
# fgvc-aircraft-2013b/data/images/2091951.jpg
# fgvc-aircraft-2013b/data/images/1331909.jpg
# fgvc-aircraft-2013b/data/images/0732693.jpg
# fgvc-aircraft-2013b/data/images/0856823.jpg
# fgvc-aircraft-2013b/data/images/1979428.jpg
# fgvc-aircraft-2013b/data/images/1254669.jpg
# fgvc-aircraft-2013b/data/images/0979648.jpg
# fgvc-aircraft-2013b/data/images/1533873.jpg
# fgvc-aircraft-2013b/data/images/1524816.jpg
# fgvc-aircraft-2013b/data/images/0306459.jpg
# fgvc-aircraft-2013b/data/images/1561276.jpg
# fgvc-aircraft-2013b/data/images/1538836.jpg
# fgvc-aircraft-2013b/data/images/2105219.jpg
# fgvc-aircraft-2013b/data/images/0418567.jpg
# fgvc-aircraft-2013b/data/images/1679468.jpg
# fgvc-aircraft-2013b/data/images/1104208.jpg
# fgvc-aircraft-2013b/data/images/2259876.jpg
# fgvc-aircraft-2013b/data/images/1210745.jpg
# fgvc-aircraft-2013b/data/images/1514213.jpg
# fgvc-aircraft-2013b/data/images/1156456.jpg
# fgvc-aircraft-2013b/data/images/1054811.jpg
# fgvc-aircraft-2013b/data/images/0056324.jpg
# fgvc-aircraft-2013b/data/images/2199948.jpg
# fgvc-aircraft-2013b/data/images/0995278.jpg
# fgvc-aircraft-2013b/data/images/0637453.jpg
# fgvc-aircraft-2013b/data/images/0136479.jpg
# fgvc-aircraft-2013b/data/images/0745448.jpg
# fgvc-aircraft-2013b/data/images/1939689.jpg
# fgvc-aircraft-2013b/data/images/0688076.jpg
# fgvc-aircraft-2013b/data/images/0046946.jpg
# fgvc-aircraft-2013b/data/images/0960998.jpg
# fgvc-aircraft-2013b/data/images/1315141.jpg
# fgvc-aircraft-2013b/data/images/0875317.jpg
# fgvc-aircraft-2013b/data/images/0758787.jpg
# fgvc-aircraft-2013b/data/images/2084806.jpg
# fgvc-aircraft-2013b/data/images/2250823.jpg
# fgvc-aircraft-2013b/data/images/1582400.jpg
# fgvc-aircraft-2013b/data/images/1362504.jpg
# fgvc-aircraft-2013b/data/images/1001811.jpg
# fgvc-aircraft-2013b/data/images/0923502.jpg
# fgvc-aircraft-2013b/data/images/1354218.jpg
# fgvc-aircraft-2013b/data/images/1048552.jpg
# fgvc-aircraft-2013b/data/images/0114409.jpg
# fgvc-aircraft-2013b/data/images/0547519.jpg
# fgvc-aircraft-2013b/data/images/0067863.jpg
# fgvc-aircraft-2013b/data/images/0765604.jpg
# fgvc-aircraft-2013b/data/images/1223924.jpg
# fgvc-aircraft-2013b/data/images/1889569.jpg
# fgvc-aircraft-2013b/data/images/0808929.jpg
# fgvc-aircraft-2013b/data/images/1759296.jpg
# fgvc-aircraft-2013b/data/images/1762160.jpg
# fgvc-aircraft-2013b/data/images/0829998.jpg
# fgvc-aircraft-2013b/data/images/1077480.jpg
# fgvc-aircraft-2013b/data/images/2080680.jpg
# fgvc-aircraft-2013b/data/images/0810608.jpg
# fgvc-aircraft-2013b/data/images/1481649.jpg
# fgvc-aircraft-2013b/data/images/2103110.jpg
# fgvc-aircraft-2013b/data/images/1573352.jpg
# fgvc-aircraft-2013b/data/images/2213427.jpg
# fgvc-aircraft-2013b/data/images/1308404.jpg
# fgvc-aircraft-2013b/data/images/0687392.jpg
# fgvc-aircraft-2013b/data/images/1202350.jpg
# fgvc-aircraft-2013b/data/images/1223797.jpg
# fgvc-aircraft-2013b/data/images/1204178.jpg
# fgvc-aircraft-2013b/data/images/1969049.jpg
# fgvc-aircraft-2013b/data/images/0209554.jpg
# fgvc-aircraft-2013b/data/images/0117996.jpg
# fgvc-aircraft-2013b/data/images/0740888.jpg
# fgvc-aircraft-2013b/data/images/2039227.jpg
# fgvc-aircraft-2013b/data/images/1302868.jpg
# fgvc-aircraft-2013b/data/images/2029900.jpg
# fgvc-aircraft-2013b/data/images/1002746.jpg
# fgvc-aircraft-2013b/data/images/1325008.jpg
# fgvc-aircraft-2013b/data/images/1449320.jpg
# fgvc-aircraft-2013b/data/images/1415519.jpg
# fgvc-aircraft-2013b/data/images/0155611.jpg
# fgvc-aircraft-2013b/data/images/2232991.jpg
# fgvc-aircraft-2013b/data/images/1619921.jpg
# fgvc-aircraft-2013b/data/images/2083668.jpg
# fgvc-aircraft-2013b/data/images/1564412.jpg
# fgvc-aircraft-2013b/data/images/1379717.jpg
# fgvc-aircraft-2013b/data/images/1379981.jpg
# fgvc-aircraft-2013b/data/images/1373938.jpg
# fgvc-aircraft-2013b/data/images/0350198.jpg
# fgvc-aircraft-2013b/data/images/0944182.jpg
# fgvc-aircraft-2013b/data/images/0977267.jpg
# fgvc-aircraft-2013b/data/images/0048341.jpg
# fgvc-aircraft-2013b/data/images/1544976.jpg
# fgvc-aircraft-2013b/data/images/2212259.jpg
# fgvc-aircraft-2013b/data/images/1407350.jpg
# fgvc-aircraft-2013b/data/images/2175577.jpg
# fgvc-aircraft-2013b/data/images/1030324.jpg
# fgvc-aircraft-2013b/data/images/0732742.jpg
# fgvc-aircraft-2013b/data/images/1577934.jpg
# fgvc-aircraft-2013b/data/images/0622056.jpg
# fgvc-aircraft-2013b/data/images/1831096.jpg
# fgvc-aircraft-2013b/data/images/1838164.jpg
# fgvc-aircraft-2013b/data/images/1818400.jpg
# fgvc-aircraft-2013b/data/images/1587526.jpg
# fgvc-aircraft-2013b/data/images/1540149.jpg
# fgvc-aircraft-2013b/data/images/1563563.jpg
# fgvc-aircraft-2013b/data/images/0482820.jpg
# fgvc-aircraft-2013b/data/images/1756560.jpg
# fgvc-aircraft-2013b/data/images/1053554.jpg
# fgvc-aircraft-2013b/data/images/1460096.jpg
# fgvc-aircraft-2013b/data/images/0054367.jpg
# fgvc-aircraft-2013b/data/images/2171883.jpg
# fgvc-aircraft-2013b/data/images/1014380.jpg
# fgvc-aircraft-2013b/data/images/1658296.jpg
# fgvc-aircraft-2013b/data/images/0504825.jpg
# fgvc-aircraft-2013b/data/images/1025167.jpg
# fgvc-aircraft-2013b/data/images/1767104.jpg
# fgvc-aircraft-2013b/data/images/1723907.jpg
# fgvc-aircraft-2013b/data/images/0157278.jpg
# fgvc-aircraft-2013b/data/images/1596392.jpg
# fgvc-aircraft-2013b/data/images/1231168.jpg
# fgvc-aircraft-2013b/data/images/1750220.jpg
# fgvc-aircraft-2013b/data/images/1204728.jpg
# fgvc-aircraft-2013b/data/images/1783575.jpg
# fgvc-aircraft-2013b/data/images/1351592.jpg
# fgvc-aircraft-2013b/data/images/2119978.jpg
# fgvc-aircraft-2013b/data/images/1062482.jpg
# fgvc-aircraft-2013b/data/images/0155816.jpg
# fgvc-aircraft-2013b/data/images/0658065.jpg
# fgvc-aircraft-2013b/data/images/1601716.jpg
# fgvc-aircraft-2013b/data/images/0167063.jpg
# fgvc-aircraft-2013b/data/images/1915069.jpg
# fgvc-aircraft-2013b/data/images/0517837.jpg
# fgvc-aircraft-2013b/data/images/0734769.jpg
# fgvc-aircraft-2013b/data/images/2063812.jpg
# fgvc-aircraft-2013b/data/images/1804604.jpg
# fgvc-aircraft-2013b/data/images/2196365.jpg
# fgvc-aircraft-2013b/data/images/0737639.jpg
# fgvc-aircraft-2013b/data/images/0765781.jpg
# fgvc-aircraft-2013b/data/images/1027362.jpg
# fgvc-aircraft-2013b/data/images/1987430.jpg
# fgvc-aircraft-2013b/data/images/0812906.jpg
# fgvc-aircraft-2013b/data/images/1360525.jpg
# fgvc-aircraft-2013b/data/images/1404396.jpg
# fgvc-aircraft-2013b/data/images/1283206.jpg
# fgvc-aircraft-2013b/data/images/0908027.jpg
# fgvc-aircraft-2013b/data/images/1606078.jpg
# fgvc-aircraft-2013b/data/images/1736110.jpg
# fgvc-aircraft-2013b/data/images/0256997.jpg
# fgvc-aircraft-2013b/data/images/0584541.jpg
# fgvc-aircraft-2013b/data/images/1853929.jpg
# fgvc-aircraft-2013b/data/images/1333183.jpg
# fgvc-aircraft-2013b/data/images/1767653.jpg
# fgvc-aircraft-2013b/data/images/1060652.jpg
# fgvc-aircraft-2013b/data/images/1707735.jpg
# fgvc-aircraft-2013b/data/images/1275786.jpg
# fgvc-aircraft-2013b/data/images/0114448.jpg
# fgvc-aircraft-2013b/data/images/1426527.jpg
# fgvc-aircraft-2013b/data/images/1976055.jpg
# fgvc-aircraft-2013b/data/images/2036176.jpg
# fgvc-aircraft-2013b/data/images/1136155.jpg
# fgvc-aircraft-2013b/data/images/1259625.jpg
# fgvc-aircraft-2013b/data/images/2239816.jpg
# fgvc-aircraft-2013b/data/images/0361469.jpg
# fgvc-aircraft-2013b/data/images/0631812.jpg
# fgvc-aircraft-2013b/data/images/1250249.jpg
# fgvc-aircraft-2013b/data/images/0785021.jpg
# fgvc-aircraft-2013b/data/images/0778284.jpg
# fgvc-aircraft-2013b/data/images/1408171.jpg
# fgvc-aircraft-2013b/data/images/0136182.jpg
# fgvc-aircraft-2013b/data/images/0522938.jpg
# fgvc-aircraft-2013b/data/images/0543870.jpg
# fgvc-aircraft-2013b/data/images/1352316.jpg
# fgvc-aircraft-2013b/data/images/0487370.jpg
# fgvc-aircraft-2013b/data/images/0477671.jpg
# fgvc-aircraft-2013b/data/images/1961232.jpg
# fgvc-aircraft-2013b/data/images/1781350.jpg
# fgvc-aircraft-2013b/data/images/1299912.jpg
# fgvc-aircraft-2013b/data/images/1769168.jpg
# fgvc-aircraft-2013b/data/images/2130585.jpg
# fgvc-aircraft-2013b/data/images/1661665.jpg
# fgvc-aircraft-2013b/data/images/1399596.jpg
# fgvc-aircraft-2013b/data/images/2137132.jpg
# fgvc-aircraft-2013b/data/images/1126465.jpg
# fgvc-aircraft-2013b/data/images/1330701.jpg
# fgvc-aircraft-2013b/data/images/0923673.jpg
# fgvc-aircraft-2013b/data/images/2177217.jpg
# fgvc-aircraft-2013b/data/images/1879734.jpg
# fgvc-aircraft-2013b/data/images/1351340.jpg
# fgvc-aircraft-2013b/data/images/0564217.jpg
# fgvc-aircraft-2013b/data/images/1364919.jpg
# fgvc-aircraft-2013b/data/images/0478337.jpg
# fgvc-aircraft-2013b/data/images/0973082.jpg
# fgvc-aircraft-2013b/data/images/1053484.jpg
# fgvc-aircraft-2013b/data/images/2046694.jpg
# fgvc-aircraft-2013b/data/images/0770474.jpg
# fgvc-aircraft-2013b/data/images/0991569.jpg
# fgvc-aircraft-2013b/data/images/0097110.jpg
# fgvc-aircraft-2013b/data/images/0688081.jpg
# fgvc-aircraft-2013b/data/images/0255360.jpg
# fgvc-aircraft-2013b/data/images/0554928.jpg
# fgvc-aircraft-2013b/data/images/0547019.jpg
# fgvc-aircraft-2013b/data/images/1840427.jpg
# fgvc-aircraft-2013b/data/images/1271461.jpg
# fgvc-aircraft-2013b/data/images/0974733.jpg
# fgvc-aircraft-2013b/data/images/0339425.jpg
# fgvc-aircraft-2013b/data/images/0361566.jpg
# fgvc-aircraft-2013b/data/images/1831582.jpg
# fgvc-aircraft-2013b/data/images/0302924.jpg
# fgvc-aircraft-2013b/data/images/0181715.jpg
# fgvc-aircraft-2013b/data/images/1014104.jpg
# fgvc-aircraft-2013b/data/images/0075752.jpg
# fgvc-aircraft-2013b/data/images/1314181.jpg
# fgvc-aircraft-2013b/data/images/0602762.jpg
# fgvc-aircraft-2013b/data/images/0894240.jpg
# fgvc-aircraft-2013b/data/images/1355622.jpg
# fgvc-aircraft-2013b/data/images/1153404.jpg
# fgvc-aircraft-2013b/data/images/1337431.jpg
# fgvc-aircraft-2013b/data/images/1239645.jpg
# fgvc-aircraft-2013b/data/images/1499562.jpg
# fgvc-aircraft-2013b/data/images/0822340.jpg
# fgvc-aircraft-2013b/data/images/0699599.jpg
# fgvc-aircraft-2013b/data/images/1921281.jpg
# fgvc-aircraft-2013b/data/images/1514483.jpg
# fgvc-aircraft-2013b/data/images/0944239.jpg
# fgvc-aircraft-2013b/data/images/0123340.jpg
# fgvc-aircraft-2013b/data/images/1774010.jpg
# fgvc-aircraft-2013b/data/images/1241545.jpg
# fgvc-aircraft-2013b/data/images/1496926.jpg
# fgvc-aircraft-2013b/data/images/2118953.jpg
# fgvc-aircraft-2013b/data/images/0301967.jpg
# fgvc-aircraft-2013b/data/images/0447772.jpg
# fgvc-aircraft-2013b/data/images/1629116.jpg
# fgvc-aircraft-2013b/data/images/1270601.jpg
# fgvc-aircraft-2013b/data/images/1739524.jpg
# fgvc-aircraft-2013b/data/images/1357182.jpg
# fgvc-aircraft-2013b/data/images/2048576.jpg
# fgvc-aircraft-2013b/data/images/1143606.jpg
# fgvc-aircraft-2013b/data/images/1630526.jpg
# fgvc-aircraft-2013b/data/images/1555985.jpg
# fgvc-aircraft-2013b/data/images/1774329.jpg
# fgvc-aircraft-2013b/data/images/0955449.jpg
# fgvc-aircraft-2013b/data/images/1443070.jpg
# fgvc-aircraft-2013b/data/images/0625763.jpg
# fgvc-aircraft-2013b/data/images/2266079.jpg
# fgvc-aircraft-2013b/data/images/1251242.jpg
# fgvc-aircraft-2013b/data/images/1042824.jpg
# fgvc-aircraft-2013b/data/images/1316606.jpg
# fgvc-aircraft-2013b/data/images/0132975.jpg
# fgvc-aircraft-2013b/data/images/1790500.jpg
# fgvc-aircraft-2013b/data/images/1674736.jpg
# fgvc-aircraft-2013b/data/images/0454765.jpg
# fgvc-aircraft-2013b/data/images/1806229.jpg
# fgvc-aircraft-2013b/data/images/0699565.jpg
# fgvc-aircraft-2013b/data/images/1289187.jpg
# fgvc-aircraft-2013b/data/images/2067268.jpg
# fgvc-aircraft-2013b/data/images/0104814.jpg
# fgvc-aircraft-2013b/data/images/1540816.jpg
# fgvc-aircraft-2013b/data/images/1594716.jpg
# fgvc-aircraft-2013b/data/images/1908628.jpg
# fgvc-aircraft-2013b/data/images/0361351.jpg
# fgvc-aircraft-2013b/data/images/0977239.jpg
# fgvc-aircraft-2013b/data/images/1745999.jpg
# fgvc-aircraft-2013b/data/images/2031397.jpg
# fgvc-aircraft-2013b/data/images/1198431.jpg
# fgvc-aircraft-2013b/data/images/0920421.jpg
# fgvc-aircraft-2013b/data/images/1546282.jpg
# fgvc-aircraft-2013b/data/images/0279893.jpg
# fgvc-aircraft-2013b/data/images/0929800.jpg
# fgvc-aircraft-2013b/data/images/1592077.jpg
# fgvc-aircraft-2013b/data/images/1700930.jpg
# fgvc-aircraft-2013b/data/images/2048410.jpg
# fgvc-aircraft-2013b/data/images/0384109.jpg
# fgvc-aircraft-2013b/data/images/1680778.jpg
# fgvc-aircraft-2013b/data/images/1009765.jpg
# fgvc-aircraft-2013b/data/images/2259848.jpg
# fgvc-aircraft-2013b/data/images/2083822.jpg
# fgvc-aircraft-2013b/data/images/0591254.jpg
# fgvc-aircraft-2013b/data/images/1855337.jpg
# fgvc-aircraft-2013b/data/images/1895885.jpg
# fgvc-aircraft-2013b/data/images/0100263.jpg
# fgvc-aircraft-2013b/data/images/1423425.jpg
# fgvc-aircraft-2013b/data/images/1398863.jpg
# fgvc-aircraft-2013b/data/images/1251382.jpg
# fgvc-aircraft-2013b/data/images/1034793.jpg
# fgvc-aircraft-2013b/data/images/0842128.jpg
# fgvc-aircraft-2013b/data/images/0645411.jpg
# fgvc-aircraft-2013b/data/images/1097907.jpg
# fgvc-aircraft-2013b/data/images/1564950.jpg
# fgvc-aircraft-2013b/data/images/1295799.jpg
# fgvc-aircraft-2013b/data/images/0396527.jpg
# fgvc-aircraft-2013b/data/images/0184349.jpg
# fgvc-aircraft-2013b/data/images/0973264.jpg
# fgvc-aircraft-2013b/data/images/2013250.jpg
# fgvc-aircraft-2013b/data/images/1830876.jpg
# fgvc-aircraft-2013b/data/images/1025794.jpg
# fgvc-aircraft-2013b/data/images/0200888.jpg
# fgvc-aircraft-2013b/data/images/1378082.jpg
# fgvc-aircraft-2013b/data/images/1343589.jpg
# fgvc-aircraft-2013b/data/images/1992047.jpg
# fgvc-aircraft-2013b/data/images/1608084.jpg
# fgvc-aircraft-2013b/data/images/1898513.jpg
# fgvc-aircraft-2013b/data/images/1719561.jpg
# fgvc-aircraft-2013b/data/images/0395652.jpg
# fgvc-aircraft-2013b/data/images/1630525.jpg
# fgvc-aircraft-2013b/data/images/1871273.jpg
# fgvc-aircraft-2013b/data/images/1253455.jpg
# fgvc-aircraft-2013b/data/images/1714820.jpg
# fgvc-aircraft-2013b/data/images/1143413.jpg
# fgvc-aircraft-2013b/data/images/2011071.jpg
# fgvc-aircraft-2013b/data/images/0980191.jpg
# fgvc-aircraft-2013b/data/images/0765750.jpg
# fgvc-aircraft-2013b/data/images/2183458.jpg
# fgvc-aircraft-2013b/data/images/0062768.jpg
# fgvc-aircraft-2013b/data/images/1349341.jpg
# fgvc-aircraft-2013b/data/images/0657761.jpg
# fgvc-aircraft-2013b/data/images/1240217.jpg
# fgvc-aircraft-2013b/data/images/0143349.jpg
# fgvc-aircraft-2013b/data/images/2218525.jpg
# fgvc-aircraft-2013b/data/images/0643700.jpg
# fgvc-aircraft-2013b/data/images/1783026.jpg
# fgvc-aircraft-2013b/data/images/1997801.jpg
# fgvc-aircraft-2013b/data/images/1062971.jpg
# fgvc-aircraft-2013b/data/images/2245399.jpg
# fgvc-aircraft-2013b/data/images/2107240.jpg
# fgvc-aircraft-2013b/data/images/0811680.jpg
# fgvc-aircraft-2013b/data/images/0097118.jpg
# fgvc-aircraft-2013b/data/images/0523104.jpg
# fgvc-aircraft-2013b/data/images/1920543.jpg
# fgvc-aircraft-2013b/data/images/1375987.jpg
# fgvc-aircraft-2013b/data/images/1506812.jpg
# fgvc-aircraft-2013b/data/images/1187867.jpg
# fgvc-aircraft-2013b/data/images/0418691.jpg
# fgvc-aircraft-2013b/data/images/1148895.jpg
# fgvc-aircraft-2013b/data/images/1158577.jpg
# fgvc-aircraft-2013b/data/images/0174021.jpg
# fgvc-aircraft-2013b/data/images/1135961.jpg
# fgvc-aircraft-2013b/data/images/0187532.jpg
# fgvc-aircraft-2013b/data/images/2243952.jpg
# fgvc-aircraft-2013b/data/images/0735402.jpg
# fgvc-aircraft-2013b/data/images/0808933.jpg
# fgvc-aircraft-2013b/data/images/1425737.jpg
# fgvc-aircraft-2013b/data/images/0917793.jpg
# fgvc-aircraft-2013b/data/images/1664644.jpg
# fgvc-aircraft-2013b/data/images/1401585.jpg
# fgvc-aircraft-2013b/data/images/0681901.jpg
# fgvc-aircraft-2013b/data/images/0457830.jpg
# fgvc-aircraft-2013b/data/images/0179066.jpg
# fgvc-aircraft-2013b/data/images/1095664.jpg
# fgvc-aircraft-2013b/data/images/1548402.jpg
# fgvc-aircraft-2013b/data/images/1390310.jpg
# fgvc-aircraft-2013b/data/images/1498679.jpg
# fgvc-aircraft-2013b/data/images/1238215.jpg
# fgvc-aircraft-2013b/data/images/0458651.jpg
# fgvc-aircraft-2013b/data/images/1623096.jpg
# fgvc-aircraft-2013b/data/images/1085156.jpg
# fgvc-aircraft-2013b/data/images/1850439.jpg
# fgvc-aircraft-2013b/data/images/1938172.jpg
# fgvc-aircraft-2013b/data/images/0782915.jpg
# fgvc-aircraft-2013b/data/images/0944245.jpg
# fgvc-aircraft-2013b/data/images/0466768.jpg
# fgvc-aircraft-2013b/data/images/1650653.jpg
# fgvc-aircraft-2013b/data/images/1217239.jpg
# fgvc-aircraft-2013b/data/images/1602047.jpg
# fgvc-aircraft-2013b/data/images/0498307.jpg
# fgvc-aircraft-2013b/data/images/1552592.jpg
# fgvc-aircraft-2013b/data/images/1207591.jpg
# fgvc-aircraft-2013b/data/images/2241971.jpg
# fgvc-aircraft-2013b/data/images/1543498.jpg
# fgvc-aircraft-2013b/data/images/2175626.jpg
# fgvc-aircraft-2013b/data/images/1379044.jpg
# fgvc-aircraft-2013b/data/images/1469692.jpg
# fgvc-aircraft-2013b/data/images/1456007.jpg
# fgvc-aircraft-2013b/data/images/2249122.jpg
# fgvc-aircraft-2013b/data/images/1341989.jpg
# fgvc-aircraft-2013b/data/images/1726480.jpg
# fgvc-aircraft-2013b/data/images/1111113.jpg
# fgvc-aircraft-2013b/data/images/1714716.jpg
# fgvc-aircraft-2013b/data/images/0066413.jpg
# fgvc-aircraft-2013b/data/images/0916246.jpg
# fgvc-aircraft-2013b/data/images/0123345.jpg
# fgvc-aircraft-2013b/data/images/1177223.jpg
# fgvc-aircraft-2013b/data/images/1822339.jpg
# fgvc-aircraft-2013b/data/images/2076100.jpg
# fgvc-aircraft-2013b/data/images/1542646.jpg
# fgvc-aircraft-2013b/data/images/0950339.jpg
# fgvc-aircraft-2013b/data/images/1255446.jpg
# fgvc-aircraft-2013b/data/images/1657942.jpg
# fgvc-aircraft-2013b/data/images/0901498.jpg
# fgvc-aircraft-2013b/data/images/0193729.jpg
# fgvc-aircraft-2013b/data/images/1646015.jpg
# fgvc-aircraft-2013b/data/images/0907436.jpg
# fgvc-aircraft-2013b/data/images/1127082.jpg
# fgvc-aircraft-2013b/data/images/1935709.jpg
# fgvc-aircraft-2013b/data/images/1980863.jpg
# fgvc-aircraft-2013b/data/images/1695918.jpg
# fgvc-aircraft-2013b/data/images/0894213.jpg
# fgvc-aircraft-2013b/data/images/0225212.jpg
# fgvc-aircraft-2013b/data/images/0964235.jpg
# fgvc-aircraft-2013b/data/images/1387195.jpg
# fgvc-aircraft-2013b/data/images/0523140.jpg
# fgvc-aircraft-2013b/data/images/0328123.jpg
# fgvc-aircraft-2013b/data/images/2171767.jpg
# fgvc-aircraft-2013b/data/images/1486386.jpg
# fgvc-aircraft-2013b/data/images/0396593.jpg
# fgvc-aircraft-2013b/data/images/2220794.jpg
# fgvc-aircraft-2013b/data/images/1545195.jpg
# fgvc-aircraft-2013b/data/images/1018466.jpg
# fgvc-aircraft-2013b/data/images/1841489.jpg
# fgvc-aircraft-2013b/data/images/1451428.jpg
# fgvc-aircraft-2013b/data/images/1762142.jpg
# fgvc-aircraft-2013b/data/images/1931271.jpg
# fgvc-aircraft-2013b/data/images/0257552.jpg
# fgvc-aircraft-2013b/data/images/0385285.jpg
# fgvc-aircraft-2013b/data/images/1623632.jpg
# fgvc-aircraft-2013b/data/images/1203397.jpg
# fgvc-aircraft-2013b/data/images/0918627.jpg
# fgvc-aircraft-2013b/data/images/1312250.jpg
# fgvc-aircraft-2013b/data/images/0741298.jpg
# fgvc-aircraft-2013b/data/images/0750589.jpg
# fgvc-aircraft-2013b/data/images/1719897.jpg
# fgvc-aircraft-2013b/data/images/1060506.jpg
# fgvc-aircraft-2013b/data/images/0812685.jpg
# fgvc-aircraft-2013b/data/images/1691785.jpg
# fgvc-aircraft-2013b/data/images/1320095.jpg
# fgvc-aircraft-2013b/data/images/0903776.jpg
# fgvc-aircraft-2013b/data/images/1169799.jpg
# fgvc-aircraft-2013b/data/images/0092334.jpg
# fgvc-aircraft-2013b/data/images/1728005.jpg
# fgvc-aircraft-2013b/data/images/0523118.jpg
# fgvc-aircraft-2013b/data/images/1338360.jpg
# fgvc-aircraft-2013b/data/images/0602228.jpg
# fgvc-aircraft-2013b/data/images/0740912.jpg
# fgvc-aircraft-2013b/data/images/0573367.jpg
# fgvc-aircraft-2013b/data/images/0738255.jpg
# fgvc-aircraft-2013b/data/images/0525710.jpg
# fgvc-aircraft-2013b/data/images/1334213.jpg
# fgvc-aircraft-2013b/data/images/2104252.jpg
# fgvc-aircraft-2013b/data/images/1762097.jpg
# fgvc-aircraft-2013b/data/images/0296013.jpg
# fgvc-aircraft-2013b/data/images/1103400.jpg
# fgvc-aircraft-2013b/data/images/2073469.jpg
# fgvc-aircraft-2013b/data/images/1237717.jpg
# fgvc-aircraft-2013b/data/images/1298912.jpg
# fgvc-aircraft-2013b/data/images/0143336.jpg
# fgvc-aircraft-2013b/data/images/1584757.jpg
# fgvc-aircraft-2013b/data/images/0958066.jpg
# fgvc-aircraft-2013b/data/images/1981480.jpg
# fgvc-aircraft-2013b/data/images/0056297.jpg
# fgvc-aircraft-2013b/data/images/2215390.jpg
# fgvc-aircraft-2013b/data/images/2195493.jpg
# fgvc-aircraft-2013b/data/images/0988940.jpg
# fgvc-aircraft-2013b/data/images/0104828.jpg
# fgvc-aircraft-2013b/data/images/1298958.jpg
# fgvc-aircraft-2013b/data/images/0582365.jpg
# fgvc-aircraft-2013b/data/images/1187784.jpg
# fgvc-aircraft-2013b/data/images/0708633.jpg
# fgvc-aircraft-2013b/data/images/1043794.jpg
# fgvc-aircraft-2013b/data/images/2047534.jpg
# fgvc-aircraft-2013b/data/images/1740623.jpg
# fgvc-aircraft-2013b/data/images/0122393.jpg
# fgvc-aircraft-2013b/data/images/1443841.jpg
# fgvc-aircraft-2013b/data/images/0411918.jpg
# fgvc-aircraft-2013b/data/images/0693457.jpg
# fgvc-aircraft-2013b/data/images/1237706.jpg
# fgvc-aircraft-2013b/data/images/1404383.jpg
# fgvc-aircraft-2013b/data/images/1125696.jpg
# fgvc-aircraft-2013b/data/images/2248581.jpg
# fgvc-aircraft-2013b/data/images/0523223.jpg
# fgvc-aircraft-2013b/data/images/0805499.jpg
# fgvc-aircraft-2013b/data/images/1560579.jpg
# fgvc-aircraft-2013b/data/images/1500383.jpg
# fgvc-aircraft-2013b/data/images/0841849.jpg
# fgvc-aircraft-2013b/data/images/0062765.jpg
# fgvc-aircraft-2013b/data/images/1796410.jpg
# fgvc-aircraft-2013b/data/images/1870570.jpg
# fgvc-aircraft-2013b/data/images/1901003.jpg
# fgvc-aircraft-2013b/data/images/2228412.jpg
# fgvc-aircraft-2013b/data/images/1355623.jpg
# fgvc-aircraft-2013b/data/images/0962873.jpg
# fgvc-aircraft-2013b/data/images/1230368.jpg
# fgvc-aircraft-2013b/data/images/0647463.jpg
# fgvc-aircraft-2013b/data/images/1605637.jpg
# fgvc-aircraft-2013b/data/images/2032665.jpg
# fgvc-aircraft-2013b/data/images/1672431.jpg
# fgvc-aircraft-2013b/data/images/0522866.jpg
# fgvc-aircraft-2013b/data/images/1254089.jpg
# fgvc-aircraft-2013b/data/images/1379398.jpg
# fgvc-aircraft-2013b/data/images/1944650.jpg
# fgvc-aircraft-2013b/data/images/0959047.jpg
# fgvc-aircraft-2013b/data/images/0576234.jpg
# fgvc-aircraft-2013b/data/images/0725155.jpg
# fgvc-aircraft-2013b/data/images/0690074.jpg
# fgvc-aircraft-2013b/data/images/1076273.jpg
# fgvc-aircraft-2013b/data/images/1457085.jpg
# fgvc-aircraft-2013b/data/images/1246013.jpg
# fgvc-aircraft-2013b/data/images/2188372.jpg
# fgvc-aircraft-2013b/data/images/1961226.jpg
# fgvc-aircraft-2013b/data/images/2031889.jpg
# fgvc-aircraft-2013b/data/images/1224910.jpg
# fgvc-aircraft-2013b/data/images/2221641.jpg
# fgvc-aircraft-2013b/data/images/0749478.jpg
# fgvc-aircraft-2013b/data/images/2044260.jpg
# fgvc-aircraft-2013b/data/images/0741746.jpg
# fgvc-aircraft-2013b/data/images/0692381.jpg
# fgvc-aircraft-2013b/data/images/1163484.jpg
# fgvc-aircraft-2013b/data/images/1300002.jpg
# fgvc-aircraft-2013b/data/images/0312421.jpg
# fgvc-aircraft-2013b/data/images/0807954.jpg
# fgvc-aircraft-2013b/data/images/0996406.jpg
# fgvc-aircraft-2013b/data/images/1409250.jpg
# fgvc-aircraft-2013b/data/images/0958129.jpg
# fgvc-aircraft-2013b/data/images/1216713.jpg
# fgvc-aircraft-2013b/data/images/0182730.jpg
# fgvc-aircraft-2013b/data/images/1356441.jpg
# fgvc-aircraft-2013b/data/images/2186370.jpg
# fgvc-aircraft-2013b/data/images/2001289.jpg
# fgvc-aircraft-2013b/data/images/0635837.jpg
# fgvc-aircraft-2013b/data/images/2045348.jpg
# fgvc-aircraft-2013b/data/images/1769898.jpg
# fgvc-aircraft-2013b/data/images/0384438.jpg
# fgvc-aircraft-2013b/data/images/0833334.jpg
# fgvc-aircraft-2013b/data/images/0136179.jpg
# fgvc-aircraft-2013b/data/images/1931138.jpg
# fgvc-aircraft-2013b/data/images/1196360.jpg
# fgvc-aircraft-2013b/data/images/1567136.jpg
# fgvc-aircraft-2013b/data/images/2072892.jpg
# fgvc-aircraft-2013b/data/images/1314561.jpg
# fgvc-aircraft-2013b/data/images/1950559.jpg
# fgvc-aircraft-2013b/data/images/1622774.jpg
# fgvc-aircraft-2013b/data/images/0488772.jpg
# fgvc-aircraft-2013b/data/images/1383360.jpg
# fgvc-aircraft-2013b/data/images/2053589.jpg
# fgvc-aircraft-2013b/data/images/1898447.jpg
# fgvc-aircraft-2013b/data/images/1878594.jpg
# fgvc-aircraft-2013b/data/images/0756253.jpg
# fgvc-aircraft-2013b/data/images/1899232.jpg
# fgvc-aircraft-2013b/data/images/0233755.jpg
# fgvc-aircraft-2013b/data/images/1723821.jpg
# fgvc-aircraft-2013b/data/images/1927270.jpg
# fgvc-aircraft-2013b/data/images/1820323.jpg
# fgvc-aircraft-2013b/data/images/0895456.jpg
# fgvc-aircraft-2013b/data/images/0728940.jpg
# fgvc-aircraft-2013b/data/images/1245887.jpg
# fgvc-aircraft-2013b/data/images/1264191.jpg
# fgvc-aircraft-2013b/data/images/1222829.jpg
# fgvc-aircraft-2013b/data/images/2183607.jpg
# fgvc-aircraft-2013b/data/images/0737315.jpg
# fgvc-aircraft-2013b/data/images/0568803.jpg
# fgvc-aircraft-2013b/data/images/1338345.jpg
# fgvc-aircraft-2013b/data/images/1347237.jpg
# fgvc-aircraft-2013b/data/images/0917357.jpg
# fgvc-aircraft-2013b/data/images/0494862.jpg
# fgvc-aircraft-2013b/data/images/1860127.jpg
# fgvc-aircraft-2013b/data/images/2148310.jpg
# fgvc-aircraft-2013b/data/images/0978286.jpg
# fgvc-aircraft-2013b/data/images/1827565.jpg
# fgvc-aircraft-2013b/data/images/1966165.jpg
# fgvc-aircraft-2013b/data/images/1564426.jpg
# fgvc-aircraft-2013b/data/images/0999159.jpg
# fgvc-aircraft-2013b/data/images/2115317.jpg
# fgvc-aircraft-2013b/data/images/1800217.jpg
# fgvc-aircraft-2013b/data/images/1563038.jpg
# fgvc-aircraft-2013b/data/images/1428985.jpg
# fgvc-aircraft-2013b/data/images/0174903.jpg
# fgvc-aircraft-2013b/data/images/0442375.jpg
# fgvc-aircraft-2013b/data/images/0689371.jpg
# fgvc-aircraft-2013b/data/images/1543509.jpg
# fgvc-aircraft-2013b/data/images/0903658.jpg
# fgvc-aircraft-2013b/data/images/1826635.jpg
# fgvc-aircraft-2013b/data/images/2139678.jpg
# fgvc-aircraft-2013b/data/images/1072281.jpg
# fgvc-aircraft-2013b/data/images/1110775.jpg
# fgvc-aircraft-2013b/data/images/2195127.jpg
# fgvc-aircraft-2013b/data/images/2231689.jpg
# fgvc-aircraft-2013b/data/images/0901457.jpg
# fgvc-aircraft-2013b/data/images/0923548.jpg
# fgvc-aircraft-2013b/data/images/0967818.jpg
# fgvc-aircraft-2013b/data/images/0243476.jpg
# fgvc-aircraft-2013b/data/images/1879981.jpg
# fgvc-aircraft-2013b/data/images/1137745.jpg
# fgvc-aircraft-2013b/data/images/1115308.jpg
# fgvc-aircraft-2013b/data/images/1695906.jpg
# fgvc-aircraft-2013b/data/images/1520426.jpg
# fgvc-aircraft-2013b/data/images/1054095.jpg
# fgvc-aircraft-2013b/data/images/1320583.jpg
# fgvc-aircraft-2013b/data/images/2229401.jpg
# fgvc-aircraft-2013b/data/images/0440955.jpg
# fgvc-aircraft-2013b/data/images/1146067.jpg
# fgvc-aircraft-2013b/data/images/1223342.jpg
# fgvc-aircraft-2013b/data/images/1508811.jpg
# fgvc-aircraft-2013b/data/images/2020296.jpg
# fgvc-aircraft-2013b/data/images/0687278.jpg
# fgvc-aircraft-2013b/data/images/0713915.jpg
# fgvc-aircraft-2013b/data/images/1161655.jpg
# fgvc-aircraft-2013b/data/images/0229722.jpg
# fgvc-aircraft-2013b/data/images/0535113.jpg
# fgvc-aircraft-2013b/data/images/1531909.jpg
# fgvc-aircraft-2013b/data/images/1266357.jpg
# fgvc-aircraft-2013b/data/images/1026571.jpg
# fgvc-aircraft-2013b/data/images/2166443.jpg
# fgvc-aircraft-2013b/data/images/0717995.jpg
# fgvc-aircraft-2013b/data/images/2181542.jpg
# fgvc-aircraft-2013b/data/images/1182368.jpg
# fgvc-aircraft-2013b/data/images/2074641.jpg
# fgvc-aircraft-2013b/data/images/0108172.jpg
# fgvc-aircraft-2013b/data/images/2211307.jpg
# fgvc-aircraft-2013b/data/images/0075759.jpg
# fgvc-aircraft-2013b/data/images/1145212.jpg
# ...
# fgvc-aircraft-2013b/data/images/2094475.jpg
# fgvc-aircraft-2013b/data/images/2152856.jpg
# fgvc-aircraft-2013b/data/images/0554600.jpg
# fgvc-aircraft-2013b/data/images/0523192.jpg
# fgvc-aircraft-2013b/data/images/0779327.jpg
# fgvc-aircraft-2013b/data/images/0091365.jpg
# fgvc-aircraft-2013b/data/images/0810604.jpg
# fgvc-aircraft-2013b/data/images/0964344.jpg
# fgvc-aircraft-2013b/data/images/1369430.jpg
# fgvc-aircraft-2013b/data/images/0177655.jpg
# fgvc-aircraft-2013b/data/images/0394154.jpg
# fgvc-aircraft-2013b/data/images/0841712.jpg
# fgvc-aircraft-2013b/data/images/1037501.jpg
# fgvc-aircraft-2013b/data/images/0923550.jpg
# fgvc-aircraft-2013b/data/images/0638654.jpg
# fgvc-aircraft-2013b/data/images/0056331.jpg
# fgvc-aircraft-2013b/data/images/1193564.jpg
# fgvc-aircraft-2013b/data/images/0218850.jpg
# fgvc-aircraft-2013b/data/images/0383680.jpg
# fgvc-aircraft-2013b/data/images/2171061.jpg
# fgvc-aircraft-2013b/data/images/2132956.jpg
# fgvc-aircraft-2013b/data/images/0875327.jpg
# fgvc-aircraft-2013b/data/images/0994751.jpg
# fgvc-aircraft-2013b/data/images/1398764.jpg
# fgvc-aircraft-2013b/data/images/0946798.jpg
# fgvc-aircraft-2013b/data/images/1064717.jpg
# fgvc-aircraft-2013b/data/images/2085982.jpg
# fgvc-aircraft-2013b/data/images/0974653.jpg
# fgvc-aircraft-2013b/data/images/1175264.jpg
# fgvc-aircraft-2013b/data/images/0067617.jpg
# fgvc-aircraft-2013b/data/images/1052986.jpg
# fgvc-aircraft-2013b/data/images/1636570.jpg
# fgvc-aircraft-2013b/data/images/1601262.jpg
# fgvc-aircraft-2013b/data/images/0059107.jpg
# fgvc-aircraft-2013b/data/images/2197330.jpg
# fgvc-aircraft-2013b/data/images/0337959.jpg
# fgvc-aircraft-2013b/data/images/0781086.jpg
# fgvc-aircraft-2013b/data/images/0968446.jpg
# fgvc-aircraft-2013b/data/images/1149855.jpg
# fgvc-aircraft-2013b/data/images/0522910.jpg
# fgvc-aircraft-2013b/data/images/1573406.jpg
# fgvc-aircraft-2013b/data/images/0688078.jpg
# fgvc-aircraft-2013b/data/images/0275909.jpg
# fgvc-aircraft-2013b/data/images/0949946.jpg
# fgvc-aircraft-2013b/data/images/0934703.jpg
# fgvc-aircraft-2013b/data/images/0663587.jpg
# fgvc-aircraft-2013b/data/images/1521239.jpg
# fgvc-aircraft-2013b/data/images/1477073.jpg
# fgvc-aircraft-2013b/data/images/0523047.jpg
# fgvc-aircraft-2013b/data/images/2212521.jpg
# fgvc-aircraft-2013b/data/images/1109944.jpg
# fgvc-aircraft-2013b/data/images/1115131.jpg
# fgvc-aircraft-2013b/data/images/0725232.jpg
# fgvc-aircraft-2013b/data/images/0536515.jpg
# fgvc-aircraft-2013b/data/images/0849417.jpg
# fgvc-aircraft-2013b/data/images/0694464.jpg
# fgvc-aircraft-2013b/data/images/1714826.jpg
# fgvc-aircraft-2013b/data/images/0536510.jpg
# fgvc-aircraft-2013b/data/images/0993951.jpg
# fgvc-aircraft-2013b/data/images/1240315.jpg
# fgvc-aircraft-2013b/data/images/1660305.jpg
# fgvc-aircraft-2013b/data/images/1662016.jpg
# fgvc-aircraft-2013b/data/images/0514738.jpg
# fgvc-aircraft-2013b/data/images/1292174.jpg
# fgvc-aircraft-2013b/data/images/1202520.jpg
# fgvc-aircraft-2013b/data/images/1362533.jpg
# fgvc-aircraft-2013b/data/images/1935749.jpg
# fgvc-aircraft-2013b/data/images/0731604.jpg
# fgvc-aircraft-2013b/data/images/0645934.jpg
# fgvc-aircraft-2013b/data/images/1195674.jpg
# fgvc-aircraft-2013b/data/images/1189525.jpg
# fgvc-aircraft-2013b/data/images/1054081.jpg
# fgvc-aircraft-2013b/data/images/1997674.jpg
# fgvc-aircraft-2013b/data/images/0890438.jpg
# fgvc-aircraft-2013b/data/images/1914684.jpg
# fgvc-aircraft-2013b/data/images/1413133.jpg
# fgvc-aircraft-2013b/data/images/2033054.jpg
# fgvc-aircraft-2013b/data/images/1480281.jpg
# fgvc-aircraft-2013b/data/images/1099011.jpg
# fgvc-aircraft-2013b/data/images/1280503.jpg
# fgvc-aircraft-2013b/data/images/1099217.jpg
# fgvc-aircraft-2013b/data/images/1597800.jpg
# fgvc-aircraft-2013b/data/images/0227119.jpg
# fgvc-aircraft-2013b/data/images/0952726.jpg
# fgvc-aircraft-2013b/data/images/0338536.jpg
# fgvc-aircraft-2013b/data/images/1146071.jpg
# fgvc-aircraft-2013b/data/images/1598048.jpg
# fgvc-aircraft-2013b/data/images/0523168.jpg
# fgvc-aircraft-2013b/data/images/0862199.jpg
# fgvc-aircraft-2013b/data/images/0418706.jpg
# fgvc-aircraft-2013b/data/images/0697384.jpg
# fgvc-aircraft-2013b/data/images/1763290.jpg
# fgvc-aircraft-2013b/data/images/1341990.jpg
# fgvc-aircraft-2013b/data/images/1017808.jpg
# fgvc-aircraft-2013b/data/images/0483246.jpg
# fgvc-aircraft-2013b/data/images/1230274.jpg
# fgvc-aircraft-2013b/data/images/1824737.jpg
# fgvc-aircraft-2013b/data/images/1685190.jpg
# fgvc-aircraft-2013b/data/images/0136148.jpg
# fgvc-aircraft-2013b/data/images/0719828.jpg
# fgvc-aircraft-2013b/data/images/0174885.jpg
# fgvc-aircraft-2013b/data/images/0337266.jpg
# fgvc-aircraft-2013b/data/images/0066281.jpg
# fgvc-aircraft-2013b/data/images/0618871.jpg
# fgvc-aircraft-2013b/data/images/0607514.jpg
# fgvc-aircraft-2013b/data/images/2178143.jpg
# fgvc-aircraft-2013b/data/images/0838565.jpg
# fgvc-aircraft-2013b/data/images/1445587.jpg
# fgvc-aircraft-2013b/data/images/2158999.jpg
# fgvc-aircraft-2013b/data/images/1137743.jpg
# fgvc-aircraft-2013b/data/images/0888512.jpg
# fgvc-aircraft-2013b/data/images/0218812.jpg
# fgvc-aircraft-2013b/data/images/0761153.jpg
# fgvc-aircraft-2013b/data/images/0167074.jpg
# fgvc-aircraft-2013b/data/images/1155017.jpg
# fgvc-aircraft-2013b/data/images/0109440.jpg
# fgvc-aircraft-2013b/data/images/0498132.jpg
# fgvc-aircraft-2013b/data/images/0435287.jpg
# fgvc-aircraft-2013b/data/images/1398982.jpg
# fgvc-aircraft-2013b/data/images/1004797.jpg
# fgvc-aircraft-2013b/data/images/1607960.jpg
# fgvc-aircraft-2013b/data/images/0745103.jpg
# fgvc-aircraft-2013b/data/images/1389040.jpg
# fgvc-aircraft-2013b/data/images/1296872.jpg
# fgvc-aircraft-2013b/data/images/2251723.jpg
# fgvc-aircraft-2013b/data/images/0447464.jpg
# fgvc-aircraft-2013b/data/images/0383876.jpg
# fgvc-aircraft-2013b/data/images/0063291.jpg
# fgvc-aircraft-2013b/data/images/0395615.jpg
# fgvc-aircraft-2013b/data/images/0740885.jpg
# fgvc-aircraft-2013b/data/images/1940255.jpg
# fgvc-aircraft-2013b/data/images/0151656.jpg
# fgvc-aircraft-2013b/data/images/0257377.jpg
# fgvc-aircraft-2013b/data/images/2230428.jpg
# fgvc-aircraft-2013b/data/images/1482188.jpg
# fgvc-aircraft-2013b/data/images/0987741.jpg
# fgvc-aircraft-2013b/data/images/2162684.jpg
# fgvc-aircraft-2013b/data/images/2110996.jpg
# fgvc-aircraft-2013b/data/images/0582371.jpg
# fgvc-aircraft-2013b/data/images/0469653.jpg
# fgvc-aircraft-2013b/data/images/1119476.jpg
# fgvc-aircraft-2013b/data/images/0177659.jpg
# fgvc-aircraft-2013b/data/images/1254187.jpg
# fgvc-aircraft-2013b/data/images/0492491.jpg
# fgvc-aircraft-2013b/data/images/0692142.jpg
# fgvc-aircraft-2013b/data/images/0523028.jpg
# fgvc-aircraft-2013b/data/images/0181712.jpg
# fgvc-aircraft-2013b/data/images/1586136.jpg
# fgvc-aircraft-2013b/data/images/0334277.jpg
# fgvc-aircraft-2013b/data/images/1258646.jpg
# fgvc-aircraft-2013b/data/images/1471690.jpg
# fgvc-aircraft-2013b/data/images/1002385.jpg
# fgvc-aircraft-2013b/data/images/0675250.jpg
# fgvc-aircraft-2013b/data/images/2127935.jpg
# fgvc-aircraft-2013b/data/images/0118430.jpg
# fgvc-aircraft-2013b/data/images/0975825.jpg
# fgvc-aircraft-2013b/data/images/1059777.jpg
# fgvc-aircraft-2013b/data/images/1561986.jpg
# fgvc-aircraft-2013b/data/images/0435276.jpg
# fgvc-aircraft-2013b/data/images/1739526.jpg
# fgvc-aircraft-2013b/data/images/1465204.jpg
# fgvc-aircraft-2013b/data/images/1154647.jpg
# fgvc-aircraft-2013b/data/images/1505652.jpg
# fgvc-aircraft-2013b/data/images/1523895.jpg
# fgvc-aircraft-2013b/data/images/1338706.jpg
# fgvc-aircraft-2013b/data/images/1187431.jpg
# fgvc-aircraft-2013b/data/images/0523179.jpg
# fgvc-aircraft-2013b/data/images/0602442.jpg
# fgvc-aircraft-2013b/data/images/0328368.jpg
# fgvc-aircraft-2013b/data/images/0745799.jpg
# fgvc-aircraft-2013b/data/images/0062722.jpg
# fgvc-aircraft-2013b/data/images/0773533.jpg
# fgvc-aircraft-2013b/data/images/1394172.jpg
# fgvc-aircraft-2013b/data/images/1257119.jpg
# fgvc-aircraft-2013b/data/images/1663372.jpg
# fgvc-aircraft-2013b/data/images/1414282.jpg
# fgvc-aircraft-2013b/data/images/1298901.jpg
# fgvc-aircraft-2013b/data/images/0443972.jpg
# fgvc-aircraft-2013b/data/images/1204184.jpg
# fgvc-aircraft-2013b/data/images/1094669.jpg
# fgvc-aircraft-2013b/data/images/1339197.jpg
# fgvc-aircraft-2013b/data/images/0523218.jpg
# fgvc-aircraft-2013b/data/images/2123736.jpg
# fgvc-aircraft-2013b/data/images/1302049.jpg
# fgvc-aircraft-2013b/data/images/0093500.jpg
# fgvc-aircraft-2013b/data/images/1169470.jpg
# fgvc-aircraft-2013b/data/images/1542798.jpg
# fgvc-aircraft-2013b/data/images/2203480.jpg
# fgvc-aircraft-2013b/data/images/1299913.jpg
# fgvc-aircraft-2013b/data/images/0836152.jpg
# fgvc-aircraft-2013b/data/images/2217849.jpg
# fgvc-aircraft-2013b/data/images/2101956.jpg
# fgvc-aircraft-2013b/data/images/0218041.jpg
# fgvc-aircraft-2013b/data/images/2258360.jpg
# fgvc-aircraft-2013b/data/images/2259583.jpg
# fgvc-aircraft-2013b/data/images/1112805.jpg
# fgvc-aircraft-2013b/data/images/0723126.jpg
# fgvc-aircraft-2013b/data/images/1234236.jpg
# fgvc-aircraft-2013b/data/images/0187247.jpg
# fgvc-aircraft-2013b/data/images/0963485.jpg
# fgvc-aircraft-2013b/data/images/1214893.jpg
# fgvc-aircraft-2013b/data/images/0400397.jpg
# fgvc-aircraft-2013b/data/images/1426920.jpg
# fgvc-aircraft-2013b/data/images/1423432.jpg
# fgvc-aircraft-2013b/data/images/1779674.jpg
# fgvc-aircraft-2013b/data/images/1932555.jpg
# fgvc-aircraft-2013b/data/images/1541387.jpg
# fgvc-aircraft-2013b/data/images/0066410.jpg
# fgvc-aircraft-2013b/data/images/1599938.jpg
# fgvc-aircraft-2013b/data/images/1666989.jpg
# fgvc-aircraft-2013b/data/images/1174379.jpg
# fgvc-aircraft-2013b/data/images/2041416.jpg
# fgvc-aircraft-2013b/data/images/0907359.jpg
# fgvc-aircraft-2013b/data/images/2172265.jpg
# fgvc-aircraft-2013b/data/images/1085719.jpg
# fgvc-aircraft-2013b/data/images/1935338.jpg
# fgvc-aircraft-2013b/data/images/1880761.jpg
# fgvc-aircraft-2013b/data/images/1313184.jpg
# fgvc-aircraft-2013b/data/images/0921743.jpg
# fgvc-aircraft-2013b/data/images/1369269.jpg
# fgvc-aircraft-2013b/data/images/0361101.jpg
# fgvc-aircraft-2013b/data/images/1222822.jpg
# fgvc-aircraft-2013b/data/images/1900829.jpg
# fgvc-aircraft-2013b/data/images/1221649.jpg
# fgvc-aircraft-2013b/data/images/1889566.jpg
# fgvc-aircraft-2013b/data/images/1398420.jpg
# fgvc-aircraft-2013b/data/images/1085153.jpg
# fgvc-aircraft-2013b/data/images/1178011.jpg
# fgvc-aircraft-2013b/data/images/0063923.jpg
# fgvc-aircraft-2013b/data/images/1815884.jpg
# fgvc-aircraft-2013b/data/images/0725666.jpg
# fgvc-aircraft-2013b/data/images/2046587.jpg
# fgvc-aircraft-2013b/data/images/2160566.jpg
# fgvc-aircraft-2013b/data/images/1384679.jpg
# fgvc-aircraft-2013b/data/images/1004743.jpg
# fgvc-aircraft-2013b/data/images/1540100.jpg
# fgvc-aircraft-2013b/data/images/0599217.jpg
# fgvc-aircraft-2013b/data/images/1209677.jpg
# fgvc-aircraft-2013b/data/images/0726611.jpg
# fgvc-aircraft-2013b/data/images/0965611.jpg
# fgvc-aircraft-2013b/data/images/2067977.jpg
# fgvc-aircraft-2013b/data/images/1176949.jpg
# fgvc-aircraft-2013b/data/images/0977358.jpg
# fgvc-aircraft-2013b/data/images/0967566.jpg
# fgvc-aircraft-2013b/data/images/0491557.jpg
# fgvc-aircraft-2013b/data/images/1230221.jpg
# fgvc-aircraft-2013b/data/images/2218547.jpg
# fgvc-aircraft-2013b/data/images/0961452.jpg
# fgvc-aircraft-2013b/data/images/0517745.jpg
# fgvc-aircraft-2013b/data/images/0563774.jpg
# fgvc-aircraft-2013b/data/images/0793692.jpg
# fgvc-aircraft-2013b/data/images/1240215.jpg
# fgvc-aircraft-2013b/data/images/1124594.jpg
# fgvc-aircraft-2013b/data/images/1291894.jpg
# fgvc-aircraft-2013b/data/images/1186578.jpg
# fgvc-aircraft-2013b/data/images/2195128.jpg
# fgvc-aircraft-2013b/data/images/1357748.jpg
# fgvc-aircraft-2013b/data/images/1629329.jpg
# fgvc-aircraft-2013b/data/images/0497638.jpg
# fgvc-aircraft-2013b/data/images/0808930.jpg
# fgvc-aircraft-2013b/data/images/0653292.jpg
# fgvc-aircraft-2013b/data/images/0233758.jpg
# fgvc-aircraft-2013b/data/images/0181710.jpg
# fgvc-aircraft-2013b/data/images/0774293.jpg
# fgvc-aircraft-2013b/data/images/1917856.jpg
# fgvc-aircraft-2013b/data/images/1361455.jpg
# fgvc-aircraft-2013b/data/images/0977247.jpg
# fgvc-aircraft-2013b/data/images/0796447.jpg
# fgvc-aircraft-2013b/data/images/0221294.jpg
# fgvc-aircraft-2013b/data/images/2066262.jpg
# fgvc-aircraft-2013b/data/images/1323017.jpg
# fgvc-aircraft-2013b/data/images/0934121.jpg
# fgvc-aircraft-2013b/data/images/0081864.jpg
# fgvc-aircraft-2013b/data/images/0744304.jpg
# fgvc-aircraft-2013b/data/images/0102223.jpg
# fgvc-aircraft-2013b/data/images/0447928.jpg
# fgvc-aircraft-2013b/data/images/0996526.jpg
# fgvc-aircraft-2013b/data/images/0759286.jpg
# fgvc-aircraft-2013b/data/images/1070335.jpg
# fgvc-aircraft-2013b/data/images/0870232.jpg
# fgvc-aircraft-2013b/data/images/1966169.jpg
# fgvc-aircraft-2013b/data/images/1223418.jpg
# fgvc-aircraft-2013b/data/images/0233762.jpg
# fgvc-aircraft-2013b/data/images/1857543.jpg
# fgvc-aircraft-2013b/data/images/1927265.jpg
# fgvc-aircraft-2013b/data/images/1388499.jpg
# fgvc-aircraft-2013b/data/images/1076891.jpg
# fgvc-aircraft-2013b/data/images/0523111.jpg
# fgvc-aircraft-2013b/data/images/0179062.jpg
# fgvc-aircraft-2013b/data/images/1842068.jpg
# fgvc-aircraft-2013b/data/images/0225221.jpg
# fgvc-aircraft-2013b/data/images/0498138.jpg
# fgvc-aircraft-2013b/data/images/0920416.jpg
# fgvc-aircraft-2013b/data/images/0143384.jpg
# fgvc-aircraft-2013b/data/images/1787740.jpg
# fgvc-aircraft-2013b/data/images/0984879.jpg
# fgvc-aircraft-2013b/data/images/1227531.jpg
# fgvc-aircraft-2013b/data/images/0871198.jpg
# fgvc-aircraft-2013b/data/images/1008569.jpg
# fgvc-aircraft-2013b/data/images/0806578.jpg
# fgvc-aircraft-2013b/data/images/1993814.jpg
# fgvc-aircraft-2013b/data/images/1548486.jpg
# fgvc-aircraft-2013b/data/images/0438654.jpg
# fgvc-aircraft-2013b/data/images/0682207.jpg
# fgvc-aircraft-2013b/data/images/0332910.jpg
# fgvc-aircraft-2013b/data/images/1534376.jpg
# fgvc-aircraft-2013b/data/images/1429301.jpg
# fgvc-aircraft-2013b/data/images/1506896.jpg
# fgvc-aircraft-2013b/data/images/0338375.jpg
# fgvc-aircraft-2013b/data/images/0139297.jpg
# fgvc-aircraft-2013b/data/images/0114438.jpg
# fgvc-aircraft-2013b/data/images/0984996.jpg
# fgvc-aircraft-2013b/data/images/2075625.jpg
# fgvc-aircraft-2013b/data/images/2161158.jpg
# fgvc-aircraft-2013b/data/images/1159626.jpg
# fgvc-aircraft-2013b/data/images/1396940.jpg
# fgvc-aircraft-2013b/data/images/1107750.jpg
# fgvc-aircraft-2013b/data/images/1358696.jpg
# fgvc-aircraft-2013b/data/images/1192235.jpg
# fgvc-aircraft-2013b/data/images/1426513.jpg
# fgvc-aircraft-2013b/data/images/2081787.jpg
# fgvc-aircraft-2013b/data/images/2192173.jpg
# fgvc-aircraft-2013b/data/images/1539352.jpg
# fgvc-aircraft-2013b/data/images/1412918.jpg
# fgvc-aircraft-2013b/data/images/1412287.jpg
# fgvc-aircraft-2013b/data/images/1623436.jpg
# fgvc-aircraft-2013b/data/images/0738252.jpg
# fgvc-aircraft-2013b/data/images/1170309.jpg
# fgvc-aircraft-2013b/data/images/1246917.jpg
# fgvc-aircraft-2013b/data/images/1631994.jpg
# fgvc-aircraft-2013b/data/images/0524796.jpg
# fgvc-aircraft-2013b/data/images/1152266.jpg
# fgvc-aircraft-2013b/data/images/0918179.jpg
# fgvc-aircraft-2013b/data/images/1244757.jpg
# fgvc-aircraft-2013b/data/images_val.txt
# fgvc-aircraft-2013b/data/images_family_val.txt
# fgvc-aircraft-2013b/
# fgvc-aircraft-2013b/vl_tpfp.m
# fgvc-aircraft-2013b/README.md
# fgvc-aircraft-2013b/example_evaluation.m
# fgvc-aircraft-2013b/README.html
# fgvc-aircraft-2013b/vl_roc.m
# fgvc-aircraft-2013b/vl_pr.m
# fgvc-aircraft-2013b/vl_argparse.m
# fgvc-aircraft-2013b/evaluation.m
# fgvc-aircraft-2013b/data/
# fgvc-aircraft-2013b/data/images_test.txt
# fgvc-aircraft-2013b/data/images_train.txt
# fgvc-aircraft-2013b/data/images_manufacturer_train.txt
# fgvc-aircraft-2013b/data/manufacturers.txt
# fgvc-aircraft-2013b/data/families.txt
# fgvc-aircraft-2013b/data/images_family_test.txt
# fgvc-aircraft-2013b/data/images_variant_test.txt
# fgvc-aircraft-2013b/data/images_manufacturer_test.txt
# fgvc-aircraft-2013b/data/images_manufacturer_val.txt
# fgvc-aircraft-2013b/data/images_manufacturer_trainval.txt
# fgvc-aircraft-2013b/data/images_family_train.txt
# fgvc-aircraft-2013b/data/images_box.txt
# fgvc-aircraft-2013b/data/variants.txt
# fgvc-aircraft-2013b/data/images_variant_trainval.txt
# fgvc-aircraft-2013b/data/images_variant_train.txt
# fgvc-aircraft-2013b/data/images_variant_val.txt
# fgvc-aircraft-2013b/data/images_family_trainval.txt
# fgvc-aircraft-2013b/data/images_val.txt
# fgvc-aircraft-2013b/data/images_family_val.txt

# %%
import random
import numpy as np
import torch

def set_seed(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)

    # Reproducibility (slower but consistent)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

set_seed(42)

# %%
import shutil
from pathlib import Path

# Paths
ROOT = Path("fgvc-aircraft-2013b") / "data"
IMG_DIR = ROOT / "images"
OUT_DIR = Path("aircraft5")

# The 5 plane models, quoted from families.txt
TARGET_FAMILIES = {
    "Boeing 737": "B737",
    "Boeing 777": "B777",
    "A320": "A320",
    "A340": "A340",
    "A380": "A380",
}

SPLITS = {
    "train": ROOT / "images_family_train.txt",
    "val":   ROOT / "images_family_val.txt",
    "test":  ROOT / "images_family_test.txt",
}

def parse_split(path: Path):
    rows = []
    for line in path.read_text(encoding="utf-8").splitlines():
        if not line.strip():
            continue
        parts = line.split()
        img_id = parts[0]
        family = " ".join(parts[1:])
        rows.append((img_id, family))
    return rows

# Fresh output folder
if OUT_DIR.exists():
    shutil.rmtree(OUT_DIR)

# Create folders
for split in SPLITS:
    for short in TARGET_FAMILIES.values():
        (OUT_DIR / split / short).mkdir(parents=True, exist_ok=True)

# Copy files
counts = {split: {short: 0 for short in TARGET_FAMILIES.values()} for split in SPLITS}
totals = {split: 0 for split in SPLITS}

for split, split_file in SPLITS.items():
    for img_id, family in parse_split(split_file):
        if family not in TARGET_FAMILIES:
            continue
        cls = TARGET_FAMILIES[family]
        src = IMG_DIR / f"{img_id}.jpg"
        dst = OUT_DIR / split / cls / f"{img_id}.jpg"
        if src.exists():
            shutil.copy2(src, dst)
            counts[split][cls] += 1
            totals[split] += 1

print("✅ Built dataset at:", OUT_DIR.resolve())
print("Totals:", totals)
for split in counts:
    print(f"\n[{split}]")
    for cls, n in counts[split].items():
        print(f"  {cls}: {n}")
# Out:
# ✅ Built dataset at: /content/aircraft5
# Totals: {'train': 633, 'val': 632, 'test': 635}
#
# [train]
#   B737: 267
#   B777: 66
#   A320: 133
#   A340: 133
#   A380: 34
#
# [val]
#   B737: 266
#   B777: 67
#   A320: 133
#   A340: 133
#   A380: 33
#
# [test]
#   B737: 267
#   B777: 67
#   A320: 134
#   A340: 134
#   A380: 33

# %%
# !pip -q install torch torchvision torchaudio scikit-learn

import os
import numpy as np
import torch
import torch.nn as nn
from torch.utils.data import DataLoader
from torchvision import datasets, transforms, models
from sklearn.metrics import classification_report, confusion_matrix

# %%
DATA_DIR = "aircraft5"
IMG_SIZE = 224
BATCH_SIZE = 32
NUM_WORKERS = 2
EPOCHS = 10
LR = 1e-3

device = "cuda" if torch.cuda.is_available() else "cpu"
device
# Out:
# 'cuda'

# %%
import matplotlib.pyplot as plt

def plot_history(hist, title):
    epochs = range(1, len(hist["train_loss"]) + 1)

    plt.figure()
    plt.plot(epochs, hist["train_loss"], label="train loss")
    plt.plot(epochs, hist["val_loss"], label="val loss")
    plt.xlabel("Epoch"); plt.ylabel("Loss"); plt.title(f"{title} - Loss")
    plt.legend(); plt.show()

    plt.figure()
    plt.plot(epochs, hist["train_acc"], label="train acc")
    plt.plot(epochs, hist["val_acc"], label="val acc")
    plt.xlabel("Epoch"); plt.ylabel("Accuracy"); plt.title(f"{title} - Accuracy")
    plt.legend(); plt.show()

# %%
# Iteration 1
train_tfms = transforms.Compose([
    transforms.Resize((IMG_SIZE, IMG_SIZE)),
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225]),
])

eval_tfms = transforms.Compose([
    transforms.Resize((IMG_SIZE, IMG_SIZE)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225]),
])

train_ds = datasets.ImageFolder(os.path.join(DATA_DIR, "train"), transform=train_tfms)
val_ds   = datasets.ImageFolder(os.path.join(DATA_DIR, "val"),   transform=eval_tfms)
test_ds  = datasets.ImageFolder(os.path.join(DATA_DIR, "test"),  transform=eval_tfms)

class_names = train_ds.classes
num_classes = len(class_names)

train_loader = DataLoader(train_ds, batch_size=BATCH_SIZE, shuffle=True,  num_workers=NUM_WORKERS)
val_loader   = DataLoader(val_ds,   batch_size=BATCH_SIZE, shuffle=False, num_workers=NUM_WORKERS)
test_loader  = DataLoader(test_ds,  batch_size=BATCH_SIZE, shuffle=False, num_workers=NUM_WORKERS)

class_names, num_classes
# Out:
# (['A320', 'A340', 'A380', 'B737', 'B777'], 5)

# %% [markdown]
# ResNet18 model is used as the backbone. I chose ResNet18 as it has a strong baseline for image classification. It is pretrained on ImageNet so it has already learnt general visual features like edges, textures, and shapes. It is also lightweight enough to train efficiently within assignment constraints.

# %% [markdown]
# In Iteration 1, the ResNet18 backbone is frozen and only the final classifier layer is trained.
# This is because freezing most parameters reduces training time and prevents overfitting when the dataset is limited. However it may struggle to separate visually similar aircraft types like the A320 and B737.

# %%
model = models.resnet18(weights=models.ResNet18_Weights.DEFAULT)

# Freeze backbone
for p in model.parameters():
    p.requires_grad = False

# Replace classifier head
in_features = model.fc.in_features
model.fc = nn.Linear(in_features, num_classes)

model = model.to(device)

criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.fc.parameters(), lr=LR)

model
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=5, bias=True)
# )

# %%
def accuracy_from_logits(logits, y):
    preds = torch.argmax(logits, dim=1)
    return (preds == y).float().mean().item()

history = {"train_loss": [], "train_acc": [], "val_loss": [], "val_acc": []}

for epoch in range(1, EPOCHS + 1):
    # ---- train ----
    model.train()
    train_losses, train_accs = [], []

    for x, y in train_loader:
        x, y = x.to(device), y.to(device)

        optimizer.zero_grad()
        logits = model(x)
        loss = criterion(logits, y)
        loss.backward()
        optimizer.step()

        train_losses.append(loss.item())
        train_accs.append(accuracy_from_logits(logits, y))

    # ---- val ----
    model.eval()
    val_losses, val_accs = [], []
    with torch.no_grad():
        for x, y in val_loader:
            x, y = x.to(device), y.to(device)
            logits = model(x)
            loss = criterion(logits, y)

            val_losses.append(loss.item())
            val_accs.append(accuracy_from_logits(logits, y))

    tl, ta = float(np.mean(train_losses)), float(np.mean(train_accs))
    vl, va = float(np.mean(val_losses)), float(np.mean(val_accs))

    history["train_loss"].append(tl)
    history["train_acc"].append(ta)
    history["val_loss"].append(vl)
    history["val_acc"].append(va)

    print(f"Epoch {epoch:02d}/{EPOCHS} | "
          f"train loss {tl:.4f} acc {ta:.4f} | "
          f"val loss {vl:.4f} acc {va:.4f}")
# Out:
# Epoch 01/10 | train loss 1.4590 acc 0.4015 | val loss 1.3605 acc 0.4234
# Epoch 02/10 | train loss 1.2451 acc 0.5079 | val loss 1.2179 acc 0.5047
# Epoch 03/10 | train loss 1.1128 acc 0.5865 | val loss 1.1581 acc 0.5083
# Epoch 04/10 | train loss 1.0380 acc 0.6110 | val loss 1.0668 acc 0.5682
# Epoch 05/10 | train loss 0.9470 acc 0.6563 | val loss 1.0258 acc 0.5870
# Epoch 06/10 | train loss 0.8820 acc 0.7034 | val loss 0.9694 acc 0.6630
# Epoch 07/10 | train loss 0.8535 acc 0.7217 | val loss 0.9644 acc 0.6656
# Epoch 08/10 | train loss 0.8216 acc 0.7150 | val loss 0.9065 acc 0.6818
# Epoch 09/10 | train loss 0.7597 acc 0.7449 | val loss 0.8908 acc 0.6849
# Epoch 10/10 | train loss 0.7364 acc 0.7719 | val loss 0.8557 acc 0.7005

# %%
all_preds, all_true = [], []

model.eval()
with torch.no_grad():
    for x, y in test_loader:
        x = x.to(device)
        logits = model(x)
        preds = torch.argmax(logits, dim=1).cpu().numpy()
        all_preds.append(preds)
        all_true.append(y.numpy())

all_preds = np.concatenate(all_preds)
all_true = np.concatenate(all_true)

print("Classification report:")
print(classification_report(all_true, all_preds, target_names=class_names, digits=4))

cm = confusion_matrix(all_true, all_preds)
cm
# Out:
# Classification report:
#               precision    recall  f1-score   support
#
#         A320     0.5583    0.5000    0.5276       134
#         A340     0.7095    0.7836    0.7447       134
#         A380     0.3077    0.1212    0.1739        33
#         B737     0.7179    0.8577    0.7816       267
#         B777     0.7429    0.3881    0.5098        67
#
#     accuracy                         0.6787       635
#    macro avg     0.6072    0.5301    0.5475       635
# weighted avg     0.6637    0.6787    0.6599       635
# array([[ 67,   3,   3,  60,   1],
#        [ 12, 105,   4,  11,   2],
#        [  5,  15,   4,   6,   3],
#        [ 23,  12,   0, 229,   3],
#        [ 13,  13,   2,  13,  26]])

# %% [markdown]
# From the report above, we can see that the model is learning, but performance is uneven across the plane types.
#
# A380 is the biggest problem where:
# Recall = 0.1212, meaning it only correctly catches around 12% of A380s.
#
# A320 is heavily confused with B737, meaning the baseline features are not strong enough to separate similar narrow-body silhouettes.
#
# B777 has a low recall of 0.3881, meaning many B777 images are being misread as other wide-body planes.
#
# Overall iteration 1 is not bad on majority classes, but weak on minority classes.

# %%
plot_history(history, "Iteration 1")

# %% [markdown]
# From iteration 1 line graph above,
# - Training loss decreases steadily, indicating that the classifier head is learning basic patterns from the data
# - However validation loss slows down early and remains higher than the training loss.
# - Training accuracy increases gradually, but validation accuracy saturates at a relatively low level
#
# This suggests limited generalisation. With the backbone frozen, the model cannot adapt deeper visual features to aircraft-specific characteristics. As a result, learning is constrained and biased toward majority classes.

# %%
# Iteration 1 Confusion Matrix (Normalised colourway)
import matplotlib.pyplot as plt
import numpy as np

cm_norm = cm.astype(float) / cm.sum(axis=1, keepdims=True)

plt.figure(figsize=(6, 6))
plt.imshow(cm_norm, vmin=0, vmax=1, cmap="viridis", interpolation="nearest")
plt.xticks(range(num_classes), class_names, rotation=45, ha="right")
plt.yticks(range(num_classes), class_names)
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Confusion Matrix (Test) - Normalised (Per-Class Recall)")
plt.colorbar(label="Proportion (0–1)")
plt.tight_layout()
plt.show()

# %% [markdown]
# From the confusion matrix above:
# - It shows heavy bias toward majority classes, especially B737.
# - A380 is frequently misclassified as A340
# - Significant confusion exists between A320 and B737, likely due to similar narrow-body proportions and common airline liveries.
# - B777 is often misclassified as other wide-body aircraft, indicating difficulty distinguishing size and engine placement from certain viewpoints.
#
# Overall, the baseline model lacks sufficient discriminative power and is strongly affected by class imbalance, resulting in poor minority-class recall.

# %%
# Iteration 2
from torchvision import transforms

train_tfms_v2 = transforms.Compose([
    transforms.RandomResizedCrop(224, scale=(0.7, 1.0)),
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.RandomRotation(10),
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406],
                         [0.229, 0.224, 0.225]),
])

eval_tfms_v2 = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406],
                         [0.229, 0.224, 0.225]),
])

# %%
import os
from torchvision import datasets
from torch.utils.data import DataLoader

DATA_DIR = "aircraft5"
BATCH_SIZE = 32
NUM_WORKERS = 2

train_ds = datasets.ImageFolder(os.path.join(DATA_DIR, "train"), transform=train_tfms_v2)
val_ds   = datasets.ImageFolder(os.path.join(DATA_DIR, "val"),   transform=eval_tfms_v2)
test_ds  = datasets.ImageFolder(os.path.join(DATA_DIR, "test"),  transform=eval_tfms_v2)

class_names = train_ds.classes
num_classes = len(class_names)

train_loader = DataLoader(train_ds, batch_size=BATCH_SIZE, shuffle=True,  num_workers=NUM_WORKERS)
val_loader   = DataLoader(val_ds,   batch_size=BATCH_SIZE, shuffle=False, num_workers=NUM_WORKERS)
test_loader  = DataLoader(test_ds,  batch_size=BATCH_SIZE, shuffle=False, num_workers=NUM_WORKERS)

class_names
# Out:
# ['A320', 'A340', 'A380', 'B737', 'B777']

# %% [markdown]
# For iteration 2, the model is improved by unfreezing and fine-tuning the final ResNet block and the classifier head. A stronger data augmentation is also appplied. Used a learning rate scheduler to stabilise training.
# Fine-tuning allows high-level features to adapt to aircraft-specific patterns such as the fuselage, tail shape, engine placement etc. Stronger augmentation improves generalisation and reduces memorisation of the training set.

# %%
import torch
import torch.nn as nn
from torchvision import models

device = "cuda" if torch.cuda.is_available() else "cpu"

model2 = models.resnet18(weights=models.ResNet18_Weights.DEFAULT)

# Freeze everything first
for p in model2.parameters():
    p.requires_grad = False

# Unfreeze LAST residual block (layer4) for fine-tuning
for p in model2.layer4.parameters():
    p.requires_grad = True

# Replace classifier head
in_features = model2.fc.in_features
model2.fc = nn.Linear(in_features, num_classes)

model2 = model2.to(device)

criterion = nn.CrossEntropyLoss()

# Different LRs: smaller for layer4, bigger for new head
optimizer = torch.optim.Adam([
    {"params": model2.layer4.parameters(), "lr": 1e-4},
    {"params": model2.fc.parameters(),     "lr": 1e-3},
])

scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=3, gamma=0.5)

model2
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=5, bias=True)
# )

# %%
import copy
import numpy as np

def accuracy_from_logits(logits, y):
    preds = torch.argmax(logits, dim=1)
    return (preds == y).float().mean().item()

history2 = {"train_loss": [], "train_acc": [], "val_loss": [], "val_acc": []}

EPOCHS = 8
best_val_acc = -1
best_state = None

for epoch in range(1, EPOCHS + 1):
    # ---- train ----
    model2.train()
    train_losses, train_accs = [], []

    for x, y in train_loader:
        x, y = x.to(device), y.to(device)

        optimizer.zero_grad()
        logits = model2(x)
        loss = criterion(logits, y)
        loss.backward()
        optimizer.step()

        train_losses.append(loss.item())
        train_accs.append(accuracy_from_logits(logits, y))

    # ---- val ----
    model2.eval()
    val_losses, val_accs = [], []
    with torch.no_grad():
        for x, y in val_loader:
            x, y = x.to(device), y.to(device)
            logits = model2(x)
            loss = criterion(logits, y)
            val_losses.append(loss.item())
            val_accs.append(accuracy_from_logits(logits, y))

    tl, ta = float(np.mean(train_losses)), float(np.mean(train_accs))
    vl, va = float(np.mean(val_losses)), float(np.mean(val_accs))

    history2["train_loss"].append(tl)
    history2["train_acc"].append(ta)
    history2["val_loss"].append(vl)
    history2["val_acc"].append(va)

    # step LR scheduler
    scheduler.step()

    # save best checkpoint
    if va > best_val_acc:
        best_val_acc = va
        best_state = copy.deepcopy(model2.state_dict())

    print(f"Epoch {epoch:02d}/{EPOCHS} | train acc {ta:.4f} | val acc {va:.4f} | best {best_val_acc:.4f}")

# load best model
model2.load_state_dict(best_state)
print("✅ Loaded best validation weights for Iteration 2.")
iter2_best_state = copy.deepcopy(model2.state_dict())
# Out:
# Epoch 01/8 | train acc 0.4853 | val acc 0.5437 | best 0.5437
# Epoch 02/8 | train acc 0.6887 | val acc 0.6854 | best 0.6854
# Epoch 03/8 | train acc 0.8137 | val acc 0.7464 | best 0.7464
# Epoch 04/8 | train acc 0.8744 | val acc 0.7536 | best 0.7536
# Epoch 05/8 | train acc 0.9018 | val acc 0.7797 | best 0.7797
# Epoch 06/8 | train acc 0.9226 | val acc 0.8005 | best 0.8005
# Epoch 07/8 | train acc 0.9542 | val acc 0.8068 | best 0.8068
# Epoch 08/8 | train acc 0.9502 | val acc 0.8115 | best 0.8115
# ✅ Loaded best validation weights for Iteration 2.

# %%
plot_history(history2, "Iteration 2")

# %% [markdown]
# For iteration 2 line graph above:
# - Training loss decreases more rapidly than in iteration 1
# - Validation loss also decreases, but more slowly, resulting in a larger gap between the two curves.
# - Training accuracy rises faster than validation accuracy.
#
# This pattern indicates stronger learning capacity and increased model flexibility due to fine-tuning:
# - By unfreezing deeper layers, the model can now fit the training data much better.
# - The increased gap suggests mild overfitting, which is expected when moving from a frozen backbone to fine-tuning.

# %%
import numpy as np
from sklearn.metrics import classification_report, confusion_matrix

all_preds, all_true = [], []

model2.eval()
with torch.no_grad():
    for x, y in test_loader:
        x = x.to(device)
        logits = model2(x)
        preds = torch.argmax(logits, dim=1).cpu().numpy()
        all_preds.append(preds)
        all_true.append(y.numpy())

all_preds = np.concatenate(all_preds)
all_true = np.concatenate(all_true)

print(classification_report(all_true, all_preds, target_names=class_names, digits=4))
cm2 = confusion_matrix(all_true, all_preds)
cm2
# Out:
#               precision    recall  f1-score   support
#
#         A320     0.7769    0.7015    0.7373       134
#         A340     0.7697    0.8731    0.8182       134
#         A380     0.6897    0.6061    0.6452        33
#         B737     0.8345    0.9064    0.8689       267
#         B777     0.7674    0.4925    0.6000        67
#
#     accuracy                         0.7969       635
#    macro avg     0.7676    0.7159    0.7339       635
# weighted avg     0.7941    0.7969    0.7904       635
# array([[ 94,   5,   1,  32,   2],
#        [  7, 117,   2,   3,   5],
#        [  1,   6,  20,   4,   2],
#        [ 13,   9,   2, 242,   1],
#        [  6,  15,   4,   9,  33]])

# %% [markdown]
# From iteration 2 report above, there are big improvements.
# - Overall accuracy jumps from 67.9% to 79.7%
# - A380 improvess massively where recall goes from 0.1212 to 0.6061. This shows that fine-tuning  + augmentation helped the model learn aircraft-specific cues instead of only generic ImageNet features.
# - A320 improves from recall of 0.5 to 0.7015
# - B737 improves from recall 0.7836 to 0.8731
# - B737 is the best class with recall of 0.9026, probably because it has the most data and consistent visual features.
# - B777 recall is still only 0.5075 which fits the "wide body" ambiguity problem.

# %%
import matplotlib.pyplot as plt
import numpy as np
import torch

def unnormalize(img):
    mean = torch.tensor([0.485, 0.456, 0.406]).view(3,1,1)
    std  = torch.tensor([0.229, 0.224, 0.225]).view(3,1,1)
    return (img * std + mean).clamp(0,1)

def show_misclassified(dataset, y_true, y_pred, class_names, n=9):
    wrong = np.where(y_true != y_pred)[0]
    print("Misclassified:", len(wrong))
    n = min(n, len(wrong))

    plt.figure(figsize=(10,10))
    for i in range(n):
        idx = wrong[i]
        img, _ = dataset[idx]
        img = unnormalize(img)

        plt.subplot(3,3,i+1)
        plt.imshow(img.permute(1,2,0))
        plt.axis("off")
        plt.title(f"T: {class_names[y_true[idx]]}\nP: {class_names[y_pred[idx]]}")
    plt.tight_layout()
    plt.show()

# %%
show_misclassified(test_ds, all_true, all_preds, class_names, n=9)
# Out:
# Misclassified: 129

# %%
# Iteration 2 Confusion Matrix (Normalised colourway)
import matplotlib.pyplot as plt
import numpy as np

cm2_norm = cm2.astype(float) / cm2.sum(axis=1, keepdims=True)

plt.figure(figsize=(6, 6))
plt.imshow(cm2_norm, vmin=0, vmax=1,cmap="viridis", interpolation="nearest")
plt.xticks(range(num_classes), class_names, rotation=45, ha="right")
plt.yticks(range(num_classes), class_names)
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Confusion Matrix (Test) - Normalised (Per-Class Recall)")
plt.colorbar(label="Proportion (0–1)")
plt.tight_layout()
plt.show()

# %% [markdown]
# For the confusion matrix above:
# - The diagonal of the confusion matrix becomes more obvious and pronounced, indicating improved correct classification.
# - A380 recall improves substantially, with fewer misclassifications into other Airbus or Boeing families.
# - A340 and B737 achieve high recall, showing strong class separation.
# - B777 still exhibits confusion with other wide-body aircrafts, but less severe than in iteration 1.
#
# Iteration 2 delivers the largest overall performance improvement. Fine-tuning and augmentation significantly enhance feature discrimination and reduce systematic misclassification.

# %%
import numpy as np
from collections import Counter

train_labels = [y for _, y in train_ds.samples]
counts = Counter(train_labels)

print("Class order:", class_names)
print("Train counts:")
for i, name in enumerate(class_names):
    print(f"{name}: {counts[i]}")

# The result below shows that there is a crazy imbalance, where A380 has only 34 samples whereas B737 has 267
# Out:
# Class order: ['A320', 'A340', 'A380', 'B737', 'B777']
# Train counts:
# A320: 133
# A340: 133
# A380: 34
# B737: 267
# B777: 66

# %%
from collections import Counter
import numpy as np
import torch
import torch.nn as nn

# get class labels from training dataset
train_labels = [y for _, y in train_ds.samples]

# count samples per class
counts = Counter(train_labels)

# build count array in correct class index order
count_arr = np.array(
    [counts[i] for i in range(len(class_names))],
    dtype=np.float32
)

# inverse frequency weighting
weights = count_arr.sum() / (len(count_arr) * count_arr)

# convert to tensor
weights = torch.tensor(weights, dtype=torch.float32).to(device)

# weighted loss
criterion3 = nn.CrossEntropyLoss(weight=weights)

# %% [markdown]
# The tensor order is A320, A340, A380, B737, B777. Made it such that the weights of A380 is very high and weights for B737 is very low to balance them out. It also tells the loss function that mistakes on the A380 matters more than the other plane models. So the model will be pushed to focus more on the A380 and not overfit the B737.

# %%
# Iteration 3: weighted loss + reset optimizer/scheduler
import copy
import numpy as np
import torch
import torch.nn as nn
from torchvision import models

EPOCHS = 10
best_val_acc = -1
best_state3 = None
history_weighted = {"train_loss": [], "train_acc": [], "val_loss": [], "val_acc": []}

# 1) Rebuild the same Iter2 model architecture
model3 = models.resnet18(weights=models.ResNet18_Weights.DEFAULT)

# Freeze everything first
for p in model3.parameters():
    p.requires_grad = False

# Unfreeze LAST residual block (layer4)
for p in model3.layer4.parameters():
    p.requires_grad = True

# Replace classifier head
in_features = model3.fc.in_features
model3.fc = nn.Linear(in_features, num_classes)

model3 = model3.to(device)

# 2) Load Iteration 2 best weights (captured after Iter2)
model3.load_state_dict(iter2_best_state)

# 3) Weighted loss (you already computed weights in Cell 23)
criterion3 = nn.CrossEntropyLoss(weight=weights)

# 4) RESET optimizer + scheduler (no carry-over)
optimizer3 = torch.optim.Adam([
    {"params": model3.layer4.parameters(), "lr": 1e-4},
    {"params": model3.fc.parameters(),     "lr": 1e-3},
])
scheduler3 = torch.optim.lr_scheduler.StepLR(optimizer3, step_size=3, gamma=0.5)

# 5) Train + validate
for epoch in range(1, EPOCHS + 1):
    # ---- train ----
    model3.train()
    train_losses, train_accs = [], []

    for x, y in train_loader:
        x, y = x.to(device), y.to(device)

        optimizer3.zero_grad()
        logits = model3(x)
        loss = criterion3(logits, y)
        loss.backward()
        optimizer3.step()

        train_losses.append(loss.item())
        train_accs.append((logits.argmax(1) == y).float().mean().item())

    # ---- val ----
    model3.eval()
    val_losses, val_accs = [], []
    with torch.no_grad():
        for x, y in val_loader:
            x, y = x.to(device), y.to(device)
            logits = model3(x)
            loss = criterion3(logits, y)

            val_losses.append(loss.item())
            val_accs.append((logits.argmax(1) == y).float().mean().item())

    scheduler3.step()

    tl, ta = float(np.mean(train_losses)), float(np.mean(train_accs))
    vl, va = float(np.mean(val_losses)), float(np.mean(val_accs))

    history_weighted["train_loss"].append(tl)
    history_weighted["train_acc"].append(ta)
    history_weighted["val_loss"].append(vl)
    history_weighted["val_acc"].append(va)

    if va > best_val_acc:
        best_val_acc = va
        best_state3 = copy.deepcopy(model3.state_dict())

    print(f"Epoch {epoch:02d}/{EPOCHS} | train acc {ta:.4f} | val acc {va:.4f} | best {best_val_acc:.4f}")

# load best model for Iteration 3
model3.load_state_dict(best_state3)
print("✅ Loaded best validation weights for Iteration 3 (weighted loss).")
# Out:
# Epoch 01/10 | train acc 0.9246 | val acc 0.7990 | best 0.7990
# Epoch 02/10 | train acc 0.9453 | val acc 0.8172 | best 0.8172
# Epoch 03/10 | train acc 0.9672 | val acc 0.7990 | best 0.8172
# Epoch 04/10 | train acc 0.9777 | val acc 0.8193 | best 0.8193
# Epoch 05/10 | train acc 0.9699 | val acc 0.8307 | best 0.8307
# Epoch 06/10 | train acc 0.9839 | val acc 0.8313 | best 0.8313
# Epoch 07/10 | train acc 0.9792 | val acc 0.8276 | best 0.8313
# Epoch 08/10 | train acc 0.9902 | val acc 0.8375 | best 0.8375
# Epoch 09/10 | train acc 0.9859 | val acc 0.8333 | best 0.8375
# Epoch 10/10 | train acc 0.9922 | val acc 0.8333 | best 0.8375
# ✅ Loaded best validation weights for Iteration 3 (weighted loss).

# %%
import numpy as np
from sklearn.metrics import classification_report, confusion_matrix

all_preds, all_true = [], []

model3.eval()
with torch.no_grad():
    for x, y in test_loader:
        x = x.to(device)
        logits = model3(x)
        preds = logits.argmax(1).cpu().numpy()
        all_preds.append(preds)
        all_true.append(y.numpy())

all_preds = np.concatenate(all_preds)
all_true = np.concatenate(all_true)

print(classification_report(all_true, all_preds, target_names=class_names, digits=4))
cm_weighted = confusion_matrix(all_true, all_preds)
cm_weighted
# Out:
#               precision    recall  f1-score   support
#
#         A320     0.7619    0.7164    0.7385       134
#         A340     0.8559    0.7537    0.8016       134
#         A380     0.8276    0.7273    0.7742        33
#         B737     0.8227    0.9213    0.8693       267
#         B777     0.6984    0.6567    0.6769        67
#
#     accuracy                         0.8047       635
#    macro avg     0.7933    0.7551    0.7721       635
# weighted avg     0.8040    0.8047    0.8021       635
# array([[ 96,   2,   1,  35,   0],
#        [ 13, 101,   2,   6,  12],
#        [  0,   2,  24,   3,   4],
#        [ 11,   6,   1, 246,   3],
#        [  6,   7,   1,   9,  44]])

# %% [markdown]
# From iteration 3, applying Weighted CrossEntropyLoss successfully mitigates class imbalance by prioritising minority classes during training.
# - A380 recall improves further from 0.6061 to 0.7273, f1-score increases from 0.6452 to 0.7742.
# - B777 recall improves substantially from 0.4925 to 0.6567
# - Macro F1 improves notably, indicating more balanced performance across all classes.
#
# While the overall accuracy gain is modest, the improvement in minority-class recall and macro F1 demonstrates a fairer and more robust classifier.

# %%
plot_history(history_weighted, "Iteration 3")

# %% [markdown]
# For iteration 3 line graph above:
# - Training loss continues to decrease and training accuracy increases to very high levels, indicating strong fitting to the training data.
# - Validation accuracy improves overall but fluctuates across epochs, reaching a peak before slightly decreasing in the next 2 epochs.
#
# This suggests that the weighted-loss model reaches optimal generalisation mid-training, after which mild overfitting begins. Therefore loading the best validation checkpoint is therefore necessary, and weighted loss successfully improves class-balanced learning without destabilising training.

# %%
show_misclassified(test_ds, all_true, all_preds, class_names, n=9)
# Out:
# Misclassified: 124

# %%
# Iteration 3 Confusion Matrix (Normalised colourway)
import matplotlib.pyplot as plt
import numpy as np

cmw_norm = cm_weighted.astype(float) / cm_weighted.sum(axis=1, keepdims=True)

plt.figure(figsize=(6, 6))
plt.imshow(cmw_norm, vmin=0, vmax=1,cmap="viridis", interpolation="nearest")
plt.colorbar(label="Proportion (0–1)")
ticks = np.arange(len(class_names))
plt.xticks(ticks, class_names, rotation=45, ha="right")
plt.yticks(ticks, class_names)
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Confusion Matrix (Weighted Loss) - Normalised (Per-Class Recall)")
plt.tight_layout()
plt.show()

# %% [markdown]
# For the confusion matrix above,
# - The confusion matrix becomes more balanced across classes.
# - A380 classifications increased more, showing that weighted loss successfully improves minority-class recognition.
# - B777 predictions improve, with more samples correctly classified and fewer being absorbed into majority classes.
# - While B737 remains the strongest class, it no longer dominates predictions as heavily as in iteration 1.
#
# This suggests that applying weighted loss effectively mitigates class imbalance, resulting in more balanced and fair performance within the plane types while maintaining strong recognition of majority classes.
